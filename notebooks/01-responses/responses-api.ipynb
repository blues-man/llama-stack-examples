# %% [markdown]
# # Some ways to use the Responses API in Llama Stack
#
# The development of this notebook was assisted by Google Gemini and Cursor using Claude 4 Sonnet.
#
# Before getting started, follow the following steps.
#
# First install Llama Stack and all of the other dependencies for this notebook.
# One way to do that is:
#
# - First install Python 3.12 or later (do not try this with older versions of Python: it will not work).
# - Then make a Python virtual environment.
# - Then within that virtual environment run:
#
# ```
# pip install -r requirements.txt
# ```
#
# Once everything is installed, run the Llama Stack server:
#
# ```
# llama stack run run.yaml --image-type venv
# ```
#
# Also run the National Parks Service Model Context Protocol (MCP) server:
#
# ```
# python nps_mcp_server.py --transport sse --port 3005
# ```
#
# See [README_NPS](../README_NPS.md) for more information about this server.

# %% [markdown]
# ## Configuration
#
# Here we point to the locations of the servers we just started up above.  Also, we provide the model ID for the model we want to use.  The model ID should be one that that is specified in [run.yaml](./run.yaml).  In the [run.yaml](./run.yaml) included here, we have the following models defined:
#
# - `openai/gpt-3.5-turbo` and `openai/gpt4o` are models from OpenAI.  They will only work if you have OPENAI_API_KEY set in your environment to a [valid OpenAI API key](https://help.openai.com/en/articles/4936850-where-do-i-find-my-openai-api-key).
# - `llama-openai-compat/Llama-3.3-70B-Instruct` is a a model from Meta Llama.  This will only work if you have LLAMA_API_KEY set in your environment to a valid API key for the hosted [Llama API](https://www.llama.com/products/llama-api/).
# - `watsonx/Llama-3.3-70B-Instruct` is the same model running on watsonx.ai (which has a somewhat different style for model IDs).  This will only work if you have a WATSONX_API_KEY and WATSONX_PROJECT_ID set (which requires an IBM Cloud account).  You may also need to set WATSONX_BASE_URL set if your watsonx.ai instance is running anywhere other than US South (which is the default).  Note that the watsonx provider in Llama Stack was [not working](https://github.com/llamastack/llama-stack/issues/3165) when this notebook was created, but hopefully it will work by the time you read this.
#
# If you can't or don't want to get any of those API keys, you can update [run.yaml](./run.yaml) to use [another inference provider](https://llama-stack.readthedocs.io/en/latest/providers/inference/index.html#overview).  Llama Stack includes numerous providers for calling hosted models like the ones above.  It also includes providers to call models that you deploy and run yourself using a model serving capability, e.g., the [vLLM provider](https://llama-stack.readthedocs.io/en/latest/providers/inference/remote_vllm.html) or the [ollama provider](https://llama-stack.readthedocs.io/en/latest/providers/inference/remote_ollama.html).
#
# Debugging Tip: If you get a connection error, make sure the port used in the definition of LLAMA_STACK_URL above, is the same port shown in the output of the `llama stack run` command in your terminal window.

# %%
LLAMA_STACK_URL = "http://localhost:8321/"
NPS_MCP_URL = "http://localhost:3005/sse/"
LLAMA_STACK_MODEL_IDS = [
    "openai/gpt-3.5-turbo",
    "openai/gpt-4o",
    "llama-openai-compat/Llama-3.3-70B-Instruct",
    "watsonx-Llama-3.3-70B-Instruct"
]

# Using gpt-4o for this demo, but feel free to try one of the others or add more to run.yaml.
LLAMA_STACK_MODEL_ID = LLAMA_STACK_MODEL_IDS[1]

# %% [markdown]
# ## Using the Llama Stack client
#
# The most obvious way to use the Responses API in Llama Stack is via the Llama Stack client.  That's the way that is most seamlessly integrated with Llama Stack itself, so we would recommend it for most beginning users who don't already have a commitment to another client library.  Here are some examples using this approach.

# %%
from llama_stack_client import LlamaStackClient

client = LlamaStackClient(base_url=LLAMA_STACK_URL)

# %%
client.chat.completions.create(
    model=LLAMA_STACK_MODEL_ID,
    messages=[{"role": "user", "content": "What is the capital of France?"}]
)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/openai/v1/chat/completions "HTTP/1.1 200 OK"
# OpenAIChatCompletion(id='chatcmpl-CMIvJ6m3H1kBxIqAaXxNd475sqj3W', choices=[OpenAIChatCompletionChoice(finish_reason='stop', index=0, message=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParam(role='assistant', content='The capital of France is Paris.', name=None, tool_calls=None, refusal=None, annotations=[], audio=None, function_call=None), logprobs=None)], created=1759431993, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_f33640a400', usage={'completion_tokens': 7, 'prompt_tokens': 14, 'total_tokens': 21, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, metrics=[{'trace_id': '3d515535eac727d1b2a3c66425023c48', 'span_id': '091af22cbac3104a', 'timestamp': '2025-10-02T19:06:34.071164Z', 'attributes': {'model_id': 'openai/gpt-4o', 'provider_id': 'openai'}, 'type': 'metric', 'metric': 'prompt_tokens', 'value': 14, 'unit': 'tokens'}, {'trace_id': '3d515535eac727d1b2a3c66425023c48', 'span_id': '091af22cbac3104a', 'timestamp': '2025-10-02T19:06:34.071192Z', 'attributes': {'model_id': 'openai/gpt-4o', 'provider_id': 'openai'}, 'type': 'metric', 'metric': 'completion_tokens', 'value': 7, 'unit': 'tokens'}, {'trace_id': '3d515535eac727d1b2a3c66425023c48', 'span_id': '091af22cbac3104a', 'timestamp': '2025-10-02T19:06:34.071198Z', 'attributes': {'model_id': 'openai/gpt-4o', 'provider_id': 'openai'}, 'type': 'metric', 'metric': 'total_tokens', 'value': 21, 'unit': 'tokens'}])

# %% [markdown]
# ### Plain model inference
#
# We will start with a simple but powerful use case in which the generative AI model provides a response directly without needing extra content or tools:

# %%
simple_llama_stack_client_response = client.responses.create(
    model=LLAMA_STACK_MODEL_ID,
    input="What is the capital of France?"
)

simple_llama_stack_client_response
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/openai/v1/responses "HTTP/1.1 200 OK"
# ResponseObject(id='resp-c5639a0b-95d3-469a-a6ec-c3c5a8bfdc1b', created_at=1759431994, model='openai/gpt-4o', object='response', output=[OutputOpenAIResponseMessage(content=[OutputOpenAIResponseMessageContentUnionMember2(annotations=[], text='The capital of France is Paris.', type='output_text')], role='assistant', type='message', id='msg_0744db49-8b70-4411-8e4f-65481a768d81', status='completed')], parallel_tool_calls=False, status='completed', text=Text(format=TextFormat(type='text', description=None, name=None, schema_=None, strict=None)), error=None, previous_response_id=None, temperature=None, top_p=None, truncation=None, user=None)

# %% [markdown]
# The response object is a little complex to read, so we provide a function to print it out in a more readable format:

# %%
def print_simple_response(response):
    print(f"ID: {response.id}")
    print(f"Status: {response.status}")
    print(f"Model: {response.model}")
    print(f"Created at: {response.created_at}")
    print(f"Output type: {response.output[0].type}")
    print(f"Response content: {response.output[0].content[0].text}")

# %%
print_simple_response(simple_llama_stack_client_response)
# Out:
# ID: resp-c5639a0b-95d3-469a-a6ec-c3c5a8bfdc1b
# Status: completed
# Model: openai/gpt-4o
# Created at: 1759431994
# Output type: message
# Response content: The capital of France is Paris.

# %% [markdown]
# ### Retrieval-Augmented Generation
#
# Next we will expand out to enabling the model to use context from a document to complement its own internal knowledge.
#
# To keep the example simple, we will just get one document, specifically a PDF file describing the US National Parks.

# %%
import requests
from pathlib import Path

# Download a sample PDF for demonstration
def download_sample_pdf(url: str, filename: str) -> str:
    """Download a PDF from URL and save it locally"""
    print(f"Downloading PDF from: {url}")
    response = requests.get(url)
    response.raise_for_status()
    
    filepath = Path(filename)
    with open(filepath, 'wb') as f:
        f.write(response.content)
    
    print(f"PDF saved as: {filepath}")
    return str(filepath)

pdf_url = "https://www.nps.gov/aboutus/upload/NPIndex2012-2016.pdf"
pdf_path = download_sample_pdf(pdf_url, "NPIndex2012-2016.pdf")
pdf_title = "The National Parks: Index 2012-2016"
# Out:
# Downloading PDF from: https://www.nps.gov/aboutus/upload/NPIndex2012-2016.pdf
# PDF saved as: NPIndex2012-2016.pdf

# %% [markdown]
# Then we create a vector store and load the PDF file into that vector store.

# %%
import uuid

vector_store_name= f"vec_{str(uuid.uuid4())[0:8]}"

vector_store = client.vector_stores.create(name=vector_store_name)
vector_store_id = vector_store.id

vector_store_id
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/openai/v1/vector_stores "HTTP/1.1 200 OK"
# 'vs_8715bef2-0dee-4d0a-9047-6cbd8795590f'

# %%
file_create_response = client.files.create(file=Path(pdf_path), purpose="assistants")
file_create_response
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/openai/v1/files "HTTP/1.1 200 OK"
# File(id='file-718d60e787fd47f1a2c226213487a2d7', bytes=6540612, created_at=1759431996, expires_at=1790967996, filename='NPIndex2012-2016.pdf', object='file', purpose='assistants')

# %%
file_ingest_response = client.vector_stores.files.create(
    vector_store_id=vector_store_id,
    file_id=file_create_response.id,
)
file_ingest_response
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/openai/v1/vector_stores/vs_8715bef2-0dee-4d0a-9047-6cbd8795590f/files "HTTP/1.1 200 OK"
# VectorStoreFile(id='file-718d60e787fd47f1a2c226213487a2d7', attributes={}, chunking_strategy=ChunkingStrategyVectorStoreChunkingStrategyAuto(type='auto'), created_at=1759431996, object='vector_store.file', status='completed', usage_bytes=0, vector_store_id='vs_8715bef2-0dee-4d0a-9047-6cbd8795590f', last_error=None)

# %% [markdown]
# Now we can uses the Responses API with that vector store to get answers from that PDF file.

# %%
rag_llama_stack_client_response = client.responses.create(
    model=LLAMA_STACK_MODEL_ID,
    input="When did the Bering Land Bridge become a national preserve?",
    tools=[
        {
            "type": "file_search",
            "vector_store_ids": [vector_store_id],
        }
    ]
)

# Here and below, we've commented out the responses to avoid cluttering the notebook.
# You can uncomment them to see the response objects.

#rag_llama_stack_client_response
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/openai/v1/responses "HTTP/1.1 200 OK"

# %% [markdown]
# This one is a little more complicated, so we will need a more powerful print method to see it all nicely formatted:

# %%
def print_rag_response(response):
    print(f"ID: {response.id}")
    print(f"Status: {response.status}")
    print(f"Model: {response.model}")
    print(f"Created at: {response.created_at}")
    print(f"Output items: {len(response.output)}")
    
    for i, output_item in enumerate(response.output):
        if len(response.output) > 1:
            print(f"\n--- Output Item {i+1} ---")
        print(f"Output type: {output_item.type}")
        
        if output_item.type in ("text", "message"):
            print(f"Response content: {output_item.content[0].text}")
        elif output_item.type == "file_search_call":
            print(f"  Tool Call ID: {output_item.id}")
            print(f"  Tool Status: {output_item.status}")
            # 'queries' is a list, so we join it for clean printing
            print(f"  Queries: {', '.join(output_item.queries)}")
            # Display results if they exist, otherwise note they are empty
            print(f"  Results: {output_item.results if output_item.results else 'None'}")
        else:
            print(f"Response content: {output_item.content}")

# %%
print_rag_response(rag_llama_stack_client_response)
# Out:
# ID: resp-dd05385f-f026-4a04-a808-625476b39a16
# Status: completed
# Model: openai/gpt-4o
# Created at: 1759432028
# Output items: 2
#
# --- Output Item 1 ---
# Output type: file_search_call
#   Tool Call ID: call_bpVIDWrKwe7ie1DgS7MQ3isT
#   Tool Status: completed
#   Queries: Bering Land Bridge national preserve establishment date
#   Results: [OutputOpenAIResponseOutputMessageFileSearchToolCallResult(attributes={}, file_id='', filename='', score=3.207261619387233, text=' for abundant wildlife and sport\n \nfishing for five species of salmon.\n \nEstablished Dec. 2, 1980. Length: 67 miles.\n \nAcreage—30,664.79 Federal: 26,417.85 \nNonfederal: 4,246.94. \nAniakchak  \nN\national Monument  and \nAniakchak  \nNational Preserve \n1000 Silver Street, Bldg.603 \nP\nO Box 245 \nKing Salmon, AK 99613 \n907\xad246\xad3305 \nwww.nps.gov/ania \nThe Aniakchak Caldera, covering some 30 square miles, is \no\nne of the great dry calderas in the world. Located in the \nvolcanically active Aleutian Mountains, the Aniakchak last \nerupted in 1931. The crater includes lava flows, cinder cones, \nand explosion pits, as well as Surprise Lake, source of the \nAniakchak River, which cascades through a 1,500\xadfoot gash \nin the crater wall. NO FEDERAL FACILITIES. \nProclaimed Aniakchak National Monument Dec. 1, 1978; \nestablished as a national monument and national preserve \nDec. 2, 1980. \nAcreage—National monument: 137,176.00, all Federal. \nNational preserve: 464,117.93 Federal: 458,809.35 \nNonfederal: 5,308.58. \nBering Land Bridge \nN\national Preserve \nPO Box 220 \nN\nome, AK\xa099762\xad0220 \n907\xad443\xad2522 \nwww.nps.gov/bela \nLocated on the Seward Peninsula, the preserve is a remnant \no\nf the land bridge that once connected Asia with North \nAmerica over 13,000 years ago. Paleontological and archeo\xad\nlogical resources abound; large populations of migratory \nbirds nest here. Ash explosion craters and lava flows, rare in \nthe Arctic, are present. LIMITED FEDERAL FACILITIES. \nProclaimed a national monument Dec. 1, 1978; established as \na national preserve Dec. 2, 1980. \nAcreage—2,697,391.01 Federal: 2,632,508.00 \nNonfederal: 64,883.01 \nCape Krusenstern \nN\national Monument \nPO Box 1029 \nK\notzebue, AK 99752\xad0029 \n907\xad442\xad3890 \nwww.nps.gov/cakr \nArcheological sites located along a succession of 114 lateral \nbeac\nh ridges illustrate Eskimo communities of every known \ncultural period in arctic Alaska, dating back some 4,000 \nyears. Nearly pristine barrier islands, lagoons, and beaches \nprovide habitat for fish, marine mammals, and migratory \nbirds while allowing legal harvest by local subsistence users. \nLIMITED FEDERAL FACILITIES. \nProclaimed Dec. 1, 1978. Boundary change: Dec. 2, 1980. \nAcreage—649,096.15 Federal: 627,190.67 \nNonfederal: 21,905.48. \n19 \n \n \n \n \n \n \n \n \n \n \n \n \n   \n   \n  \n \n  \n \n \n  \n \n \n \n  \n   \n \n  \n \n \n \n \n \n \n  \n   \n   \n \nDenali National Park and \nDenali National Preserve \nPO Box 9\n \nMcKinley Park, AK 99755\xad\n0009 \n907\xad683\xad2253\n \nwww.nps.gov/dena\n \nThe park contains North America’s highest mountain, \n20,310\xadfoot Denali.'), OutputOpenAIResponseOutputMessageFileSearchToolCallResult(attributes={}, file_id='', filename='', score=2.8739790049945815, text=' Large glaciers of the Alaska Range, cari\xad\nbou, Dall sheep, moose, grizzly bears, and timber wolves are \nhighlights of this national park and preserve. \nEstablished as Mt. McKinley National Park Feb. 26, 1917. \nSeparate Denali National Monument proclaimed Dec. 1, \n1978. Both incorporated into and established as Denali \nNational Park and Denali National Preserve Dec. 2, 1980. \nWilderness designated Dec. 2, 1980. Other boundary chang\xad\nes: Jan. 30, 1922; March 19, 1932. Designated a Biosphere \nReserve 1976. \nAcreage—National park: 4,740,911.16 Federal: \n4,732,650.51 Nonfederal: 8,260.65. Wilderness area: \n1,900,000. National preserve: 1,334,117.80 Federal: \n1,304,241.97 Nonfederal: 29,875.83. \nGates of the Arctic \nNational Park and \nGates of the Arctic \nNational Preserve \n4175 Geist Road \nFairbanks, AK 99709 \n907\xad457\xad5752 \nwww.nps.gov/gaar \nLying north of the Arctic Circle, the park and preserve include \npart of the Central Brooks Range, the northernmost extension \nof ...
#
# --- Output Item 2 ---
# Output type: message
# Response content: The Bering Land Bridge was proclaimed a national monument on December 1, 1978, and it was established as a national preserve on December 2, 1980.

# %% [markdown]
# ### MCP tool calling

# %% [markdown]
# Now we will move on to a more substantial example using the NPS MCP server you set up at the top of this notebook.

# %%
mcp_llama_stack_client_response = client.responses.create(
    model=LLAMA_STACK_MODEL_ID,
    input="Tell me about some parks in Rhode Island, and let me know if there are any upcoming events at them.",
    tools=[
        {
            "type": "mcp",
            "server_url": NPS_MCP_URL,
            "server_label": "National Parks Service tools",
        }
    ]
)

#mcp_llama_stack_client_response
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/openai/v1/responses "HTTP/1.1 200 OK"

# %% [markdown]
# The output for this one is even more complicated, so we'll add some more clauses to the print method to come up with a version that handles both RAG and MCP tool calling:

# %%
def print_response(response):
    print(f"ID: {response.id}")
    print(f"Status: {response.status}")
    print(f"Model: {response.model}")
    print(f"Created at: {response.created_at}")
    print(f"Output items: {len(response.output)}")
    
    for i, output_item in enumerate(response.output):
        if len(response.output) > 1:
            print(f"\n--- Output Item {i+1} ---")
        print(f"Output type: {output_item.type}")
        
        if output_item.type in ("text", "message"):
            print(f"Response content: {output_item.content[0].text}")
        elif output_item.type == "file_search_call":
            print(f"  Tool Call ID: {output_item.id}")
            print(f"  Tool Status: {output_item.status}")
            # 'queries' is a list, so we join it for clean printing
            print(f"  Queries: {', '.join(output_item.queries)}")
            # Display results if they exist, otherwise note they are empty
            print(f"  Results: {output_item.results if output_item.results else 'None'}")
        elif output_item.type == "mcp_list_tools":
            print_mcp_list_tools(output_item)
        elif output_item.type == "mcp_call":
            print_mcp_call(output_item)
        else:
            print(f"Response content: {output_item.content}")

def print_mcp_call(mcp_call):
    """Print MCP call in a nicely formatted way"""
    print(f"\n🛠️  MCP Tool Call: {mcp_call.name}")
    print(f"   Server: {mcp_call.server_label}")
    print(f"   ID: {mcp_call.id}")
    print(f"   Arguments: {mcp_call.arguments}")
    
    if mcp_call.error:
        print("Error: {mcp_call.error}")
    elif mcp_call.output:
        print("Output:")
        # Try to format JSON output nicely
        try:
            import json
            parsed_output = json.loads(mcp_call.output)
            print(json.dumps(parsed_output, indent=4))
        except:
            # If not valid JSON, print as-is
            print(f"   {mcp_call.output}")
    else:
        print("   ⏳ No output yet")

def print_mcp_list_tools(mcp_list_tools):
    """Print MCP list tools in a nicely formatted way"""
    print(f"\n🔧 MCP Server: {mcp_list_tools.server_label}")
    print(f"   ID: {mcp_list_tools.id}")
    print(f"   Available Tools: {len(mcp_list_tools.tools)}")
    print("=" * 80)
    
    for i, tool in enumerate(mcp_list_tools.tools, 1):
        print(f"\n{i}. {tool.name}")
        print(f"   Description: {tool.description}")
        
        # Parse and display input schema
        schema = tool.input_schema
        if schema and 'properties' in schema:
            properties = schema['properties']
            required = schema.get('required', [])
            
            print("   Parameters:")
            for param_name, param_info in properties.items():
                param_type = param_info.get('type', 'unknown')
                param_desc = param_info.get('description', 'No description')
                required_marker = " (required)" if param_name in required else " (optional)"
                print(f"     • {param_name} ({param_type}){required_marker}")
                if param_desc:
                    print(f"       {param_desc}")
        
        if i < len(mcp_list_tools.tools):
            print("-" * 40)

# %%
print_response(mcp_llama_stack_client_response)
# Out:
# ID: resp-c7024c8e-ec5d-48fa-af55-88ccdafca508
# Status: completed
# Model: openai/gpt-4o
# Created at: 1759432033
# Output items: 7
#
# --- Output Item 1 ---
# Output type: mcp_list_tools
#
# 🔧 MCP Server: National Parks Service tools
#    ID: mcp_list_ac05f13c-bfa0-409c-b981-2a56688acd98
#    Available Tools: 5
# ================================================================================
#
# 1. search_parks
#    Description: Search for national parks by state, park code, or query string.
#
# Args:
#     state_code: Two-letter state code (e.g., 'CA', 'NY')
#     park_code: Four-letter park code (e.g., 'yell', 'acad')
#     query: Search query for park names or descriptions
#     limit: Maximum number of results to return (default: 10)
#
# Returns:
#     JSON string with park information including name, description, website, and location
#    Parameters:
#      • state_code (string) (required)
#      • park_code (string) (required)
#      • query (string) (required)
#      • limit (integer) (required)
# ----------------------------------------
#
# 2. get_park_alerts
#    Description: Get current alerts for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#
# Returns:
#     JSON string with current alerts for the park
#    Parameters:
#      • park_code (string) (required)
# ----------------------------------------
#
# 3. get_park_campgrounds
#    Description: Get campground information for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of campgrounds to return (default: 10)
#
# Returns:
#     JSON string with campground information including location, amenities, and fees
#    Parameters:
#      • park_code (string) (required)
#      • limit (integer) (required)
# ----------------------------------------
#
# 4. get_park_events
#    Description: Get upcoming events for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of events to return (default: 10)
#
# Returns:
#     JSON string with event information including date, time, fee, and description
#    Parameters:
#      • park_code (string) (required)
#      • limit (integer) (required)
# ----------------------------------------
#
# 5. get_visitor_centers
#    Description: Get visitor center information for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of visitor centers to return (default: 10)
#
# Returns:
#     JSON string with visitor center information including location, contact, and operating hours
#    Parameters:
#      • park_code (string) (required)
#      • limit (integer) (required)
#
# --- Output Item 2 ---
# Output type: mcp_call
#
# 🛠️  MCP Tool Call: search_parks
#    Server: National Parks Service tools
#    ID: call_DJM5PhthJniXynL1uK82Yl5N
#    Arguments: {"state_code":"RI","park_code":"","query":"","limit":10}
# Output:
# {
#     "total": "4",
#     "parks": [
#         {
#             "name": "Blackstone River Valley National Historical Park",
#             "code": "blrv",
#             "description": "The Blackstone River powered America's entry into the Age of Industry. The success of Samuel Slater's cotton spinning mill in Pawtucket, RI touched off a chain reaction that changed how people worked and where they lived. Learn how this revolution transformed the landscape of the Blackstone Valley and the United States. The Visitor Center at Old Slater Mill is currently open Thursday-Sunday, 10-4.",
#             "website": "https://www.nps.gov/blrv/index.htm",
#             "states": "RI,MA",
#             "designation": "National Historical Park",
#             "latitude": "41.8775792792",
#             "longitude": "-71.382433945"
#         },
#         {
#             "name": "Roger Williams National Memorial",
#             "code": "rowi",
#             "description": "\"I acknowledge that to molest any person, Jew or Gentile, for either professing doctrine, or practicing worship meerly religious or spiritual, is to persecute him, and such a person (whether his doctrine or practice be true or false) suffers persecution for conscience.\" -Roger Williams, 1644 Banished by the English and saved by the First Peoples, Roger Williams founded Providence here in 1636.",
#             "website": "https://www.nps.gov/rowi/index.htm",
#             "states": "RI",
#             "designation": "National Memorial",
#             "latitude": "41.8298955",
#             "longitude": "-71.41056665"
#         },
#         {
#             "name": "Touro Synagogue National Historic Site",
#             "code": "tosy",
#             "description": "Touro Synagogue, a building of exquisite beauty and design, steeped in history and ideals, and one of the most historically significant Jewish buildings in America, was designated a National Historic Site in 1946. Dedicated in 1763, it still serves an active congregation and each year greets over 30,000 visitors who come to see the magnificent interior and hear its remarkable story.",
#             "website": "https://www.nps.gov/tosy/index.htm",
#             "states": "RI",
#             "designation": "National Historic Site",
#             "latitude": "41.4893",
#             "longitude": "-71.3121"
#         },
#         {
#             "name": "Washington-Rochambeau Revolutionary Route National Historic Trail",
#             "code": "waro",
#             "description": "\u201cOf the happiness I have enjoyed in our private friendship. The remembrance of which will be one of the most pleasing Circumstances of my life.\u201d\u2013 Comte de Rochambeau on his relationship with George Washington",
#             "website": "https://www.nps.gov/waro/index.htm",
#             "states": "MA,RI,CT,NY,NJ,PA,DE,MD,VA,DC",
#             "designation": "National Historic Trail",
#             "latitude": "40.0958204557",
#             "longitude": "-74.8563515109"
#         }
#     ]
# }
#
# --- Output Item 3 ---
# Output type: mcp_call
#
# 🛠️  MCP Tool Call: get_park_events
#    Server: National Parks Service tools
#    ID: call_cuwquR92IfMfETmI1OxIoWq2
#    Arguments: {"park_code": "blrv", "limit": 10}
# Output:
# {
#     "parkCode": "BLRV",
#     "totalEvents": 14,
#     "events": [
#         {
#             "title": "Old Slater Mill Tour",
#             "description": "<p>Join a Park Ranger on a tour of the Mill that started the American Industrial Revolution. These 30 minute guided tours investigate the historical significance of Slater Mill, and what valuable lessons the building still teachings us. Tours begin at 10:30 AM, 12:30 PM and 2:30 PM in front of the mill. Please arrive a few minutes early.</p>\n<p>\u00a0</p>\n<p><u><em>Please Note:</em></u><em>\u00a0</em><em>For visitor saftey, tours of Old Slater Mill will be modified or cancelled if the heat index is at or above 87 degrees Fahrenheit. A shortened 10 minute Ranger talk will be offered at the normal tour times. Visitors will have a brief period of access to the main part of the mill. For the latest weather information, call 401-725-8638.</em></p>",
#             "location": "67 Roosevelt Avenue, Pawtucket, RI 02860",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Old Slater Mill Tour",
#             "description": "<p>Join a Park Ranger on a tour of the Mill that started the American Industrial Revolution. These 30 minute guided tours investigate the historical significance of Slater Mill, and what valuable lessons the building still teachings us. Tours begin at 10:30 AM, 12:30 PM and 2:30 PM in front of the mill. Please arrive a few minutes early.</p>\n<p>\u00a0</p>\n<p><u><em>Please Note:</em></u><em>\u00a0</em><em>For visitor saftey, tours of Old Slater Mill will be modified or cancelled if the heat index is at or above 87 degrees Fahrenheit. A shortened 10 minute Ranger talk will be offered at the normal tour times. Visitors will have a brief period of access to the main part of the mill. For the latest weather information, call 401-725-8638.</em></p>",
#             "location": "67 Roosevelt Avenue, Pawtucket, RI 02860",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Revolutionary War Pension Files Transcription Event",
#             "description": "<p>Be a Citizen Archivist!</p>\n<p>Join Blackstone River Valley National Historical Park and North Smithfield Heritage Association for a series of free evening programs this fall. Hosted from 6-7:30 PM at Heritage Hall, 101 Greene St., North Smithfield, RI. Open to all, no registration is required.\u00a0</p>\n<p>Participants will learn about the value of pensions from the War for Independence. Rangers will talk about these sources and teach participants how to transcribe records (available online) from the National Archives. Participants are encouraged to bring a laptop or tablet for typing records. WiFi will be available for all.\u00a0</p>\n<p>DATES: October 1, November 5, and December 3, 2025</p>",
#             "location": "Meet in Heritage Hall, located at 101 Greene St., North Smithfield, RI.",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Blackstone River State Park Archaeology Tour",
#             "description": "<p>Enjoy a guided walk around\u00a0Blackstone\u00a0River State Park during Archaeology Month.\u00a0Learn how\u00a0archaeologists\u00a0have\u00a0uncovered the history of this\u00a0site.\u00a0</p>\n<p>This walk will cover some uneven terrain.</p>\n<p>Meet at\u00a01075 Lower River Road, Lincoln, RI.</p>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Voting in Our Mill Village",
#             "description": "<div class=\"x_elementToProof\">\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\"><span data-ogsc=\"\" data-olk-copy-source=\"MessageBody\">Allison Horrocks, Park Ranger at the Blackstone River Valley National Historical Park will take us back in time with a fascinating presentation of the \"how\" and \"who\" of voting in our mill villages.</span></div>\n</div>\n<div class=\"x_elementToProof\">\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\"><span data-ogsc=\"\">This presentation is part of a series events hosted by the\u00a0</span><span data-ogsc=\"\">Douglas Historical Society, a 2025-2026 Host Site for the Smithsonian Institution\u2019s Museum On Main Street\u2019s exhibit\u00a0<em data-ogsc=\"\">Voices and Votes: Democracy in America</em>. Since 1994, the Smithsonian has brought 13 different exhibits to over 1900 communities through Museum on Main Street, a part of the Smithsonian Institution Traveling Exhibition Service. Museum on Main Street is the means for the Smithsonian Institute to provide small-town America access to various museum exhibitions, research, educational resources and programming with ready-to-install exhibitions.</span></div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\"><span data-ogsc=\"\">Completed in 2000,\u00a0<em data-ogsc=\"\">Voices and Votes: Democracy in America</em>\u00a0is based on the Smithsonian\u2019s National Museum of American History permanent exhibit,\u00a0<em data-ogsc=\"\">American Democracy: A Great Leap of Faith</em>. Learn more here:\u00a0</span><span data-ogsc=\"\"><a id=\"OWA5ee1b3a0-266e-1102-39c7-c4239e17c1ef\" class=\"x_OWAAutoLink x_elementToProof\" title=\"Original URL: https://mysfpl.org/moms/. Click or tap if you trust this link.\" href=\"https://gcc02.safelinks.protection.outlook.com/?url=https%3A%2F%2Fmysfpl.org%2Fmoms%2F&amp;data=05%7C02%7CMark_Mello%40nps.gov%7C5f204d83bdd445daa54908ddfd196d31%7C0693b5ba4b184d7b9341f32f400a5494%7C0%7C0%7C638945007821407099%7CUnknown%7CTWFpbGZsb3d8eyJFbXB0eU1hcGkiOnRydWUsIlYiOiIwLjAuMDAwMCIsIlAiOiJXaW4zMiIsIkFOIjoiTWFpbCIsIldUIjoyfQ%3D%3D%7C0%7C%7C%7C&amp;sdata=AkJ9E5gaiYDxPvOhS78D5UIoooulRKfN9qquuHtrmUc%3D&amp;reserved=0\" target=\"_blank\" rel=\"noopener noreferrer\" data-auth=\"NotApplicable\" data-linkindex=\"1\" data-ogsc=\"\">Voices &amp; Votes: Democracy in America \u2013 Simon Fairfield Public Library</a>.\u00a0</span></div>\n</div>",
#             "location": "E.N. Jenckes Store Museum, 283 Main St, Douglas, MA 01516, USA",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "1670: The Jenks Settlement Walking Tour",
#             "description": "<div data-ogsc=\"black\"><em data-ogsc=\"\" data-olk-copy-source=\"MessageBody\">Presented by Old Slater Mill Association</em></div>\n<div data-ogsc=\"black\">\u00a0</div>\n<div data-ogsc=\"black\">Join interpreter Joshua\u00a0Choiniere\u202fof the Old Slater Mill Association\u00a0for a walking tour\u00a0of the original settlement of Pawtucket Village by Joseph Jenks Jr.\u00a0This tour will extend all the way up to Bayley Street.\u00a0This program will cover approximately one mile on\u00a0paved surface, with some small hills and steps. Meet in front of Sylvanus Brown House on the Old Slater Mill campus.\u202f\u00a0</div>\n<div id=\"x_Signature\">\u00a0</div>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "I Dig Slater Mill Open House",
#             "description": "<p>Experience Archaeology Month at Blackstone River Valley National Historical Park!\u202f\u00a0</p>\n<p>Learn about the archaeological digs that have taken place at Old Slater Mill and see artifacts courtesy of the Slater Industrial Archives.\u202fWatch footage of archaeologists working on the site, try hands-on activities, and conduct a search for small\u202ftreasures.\u202f \u00a0</p>\n<p>In addition to drop-in offerings, mill tours will be available at 10:30 AM., 12:30 PM., and 2:30 PM, free of charge.\u202f</p>\n<p>Visitors may also take part in a walking tour about the Pawtucket Village settlement. This walk will be led by Joshua Choiniere on Saturday, October 12, 2024, at 11:30 AM. \u00a0</p>\n<p>Presented in partnership with the Old Slater Mill Association.\u00a0</p>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Of Factories and Fiction: Gothic Tales at Slater Mill",
#             "description": "<p><span data-olk-copy-source=\"MessageBody\">The early decades of the industrial revolution gave rise to new and occasionally frightening forms of technology--this was evident in factories, but there were also changes in fiction. The Gothic novel, after all, was \"invented\" in the same year as the spinning jenny. These innovations set the stage for the development of harrowing tales about mills. During this program, visitors will learn about the history of Slater Mill through readings of historical poems, snippets from Samuel Slater's autobiography, and other primary sources.\u00a0</span></p>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Webster Walking Tour",
#             "description": "<p><span data-olk-copy-source=\"MessageBody\">Join Allison Horrocks from the National Park Service for a historic walking tour of downtown Webster. Whether you\u2019re a lifelong resident, new to the area, or just visiting for the day, you\u2019re sure to learn something new! </span></p>\n<p><span data-olk-copy-source=\"MessageBody\">This event is for all ages, and participants will meet in the lobby of the Gladys E. Kelly Public Library before the guided tour.\u00a0</span></p>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Bat Walk",
#             "description": "<p>Mark your calendars for a special Night Sky Program, featuring a Bat Walk!<br /><br />Celebrate the beginning of Bat Week on Friday, October 24, 2025, by attending this special evening event at River Bend Farm. Explore everything the night sky has to offer and get a closer view of the stars, the moon, and our neighboring planets through a telescope. For stargazing, meet in the field across from the River Bend Farm Visitor Center.<br /><br />Doors will open for Bat Week crafts and activities at 6 PM. Night Sky runs from 6:30-8:00 PM.<br /><br />All programs are free and open to the public. Registration is not required. Appropriate for all ages. All children must be accompanied by an adult. Dress for the weather. Bringing bug spray is encouraged. For the most up to date programming information, call (508) 278-7604 or visit us at\u00a0<a id=\"OWAfacdc0fc-b42e-33d7-5f4a-ed8995912f84\" class=\"x_x1fey0fg x_xmper1u x_x1edh9d7 x_OWAAutoLink x_elementToProof\" title=\"Original URL: https://bit.ly/blstupdates. Click or tap if you trust this link.\" href=\"https://gcc02.safelinks.protection.outlook.com/?url=https%3A%2F%2Fbit.ly%2Fblstupdates&amp;data=05%7C02%7CMark_Mello%40nps.gov%7C01ebe5d0efa24eec11c908ddfd08bcc9%7C0693b5ba4b184d7b9341f32f400a5494%7C0%7C0%7C638944936342132582%7CUnknown%7CTWFpbGZsb3d8eyJFbXB0eU1hcGkiOnRydWUsIlYiOiIwLjAuMDAwMCIsIlAiOiJXaW4zMiIsIkFOIjoiTWFpbCIsIldUIjoyfQ%3D%3D%7C0%7C%7C%7C&amp;sdata=PsiWUwPWfUgAo9vKKX0XuioY%2Bi4%2BptE77vgBeI%2Fxlso%3D&amp;reserved=0\" target=\"_blank\" rel=\"noopener noreferrer\" data-auth=\"NotApplicable\" data-linkindex=\"0\" data-ogsc=\"\">bit.ly/blstupdates</a></p>",
#             "location": "287 Oak Street, Uxbridge, MA",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Hopedale Walking Tour",
#             "description": "<div data-ogsc=\"black\" data-ogsb=\"white\" data-olk-copy-source=\"MessageBody\">Step back in time and explore Hopedale as it was in 1888. Hopedale has been home to many different types of workers. Hear about the various occupations that have pushed or pulled people towards Hopedale during this guided ranger tour.\u00a0</div>\n<div data-ogsc=\"black\" data-ogsb=\"white\" data-olk-copy-source=\"MessageBody\">\u00a0</div>\n<div data-ogsc=\"black\" data-ogsb=\"white\" data-olk-copy-source=\"MessageBody\">Tour begins at 43 Hope Street, Hopedale, MA.\u00a0</div>\n<div data-ogsc=\"black\" data-ogsb=\"white\">\u00a0</div>\n<div data-ogsc=\"black\" data-ogsb=\"white\">More about this series:\u00a0</div>\n<div data-ogsc=\"black\" data-ogsb=\"white\">This tour will last approximately 1 hour.\u00a0</div>\n<div data-ogsc=\"black\" data-ogsb=\"white\">\u00a0</div>\n<div data-ogsb=\"white\"><span data-ogsc=\"black\">Join a Park Ranger as we explore park sites and local communities this Fall. Tours will discuss the history of each site and its importance within the larger context of US history. Tours last about 60-90 minutes. Walking moderate distances on sometimes uneven terrain should be expected. Sturdy footwear, comfortable clothing, and water are suggested. </span></div>\n<div data-ogsb=\"white\">\u00a0</div>\n<div data-ogsb=\"white\"><span data-ogsc=\"black\">I</span><span data-ogsc=\"black\">f you have questions about accessibility, please contact Ranger\u00a0</span><span data-ogsc=\"rgb(14, 111, 163)\"><a id=\"OWA1f7e4a43-43a0-1739-74a2-6c9d9d6a57fc\" title=\"mailto:allison_horrocks@nps.gov\" href=\"mailto:allison_horrocks@nps.gov\" data-linkindex=\"5\" data-ogsc=\"rgb(14, 111, 163)\">Allison Horrocks</a></span><span data-ogsc=\"black\">.</span></div>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Revolutionary War Pension Files Transcription Even",
#             "description": "<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\" data-olk-copy-source=\"MessageBody\">Be a Citizen Archivist!</div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\">Join Blackstone River Valley National Historical Park on a quest to transcribe the pension records of local Revolutionary War veterans and widows.\u00a0</div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\">Long after their period of service had ended, veterans from the War for Independence sought recognition and compensation from their government. During this program, participants will explore the value of early pension records from America\u2019s first veterans and their widows. Participants will also learn how to transcribe these records as part of a joint initiative between the National Park Service and the National Archives and Records Administration (NARA), just in time for the 250th anniversary of the American Revolution.\u00a0</div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\">Participants\u00a0are encouraged to bring a laptop or tablet for typing records. WiFi will be available.\u00a0\u00a0</div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\">Hosted with the Massachusetts Department of Conservation &amp; Recreation (MA DCR) at Blackstone Heritage Corridor Visitor Center at Worcester. Open to all, no registration is required.\u00a0</div>\n<div id=\"x_Signature\" class=\"x_elementToProof\">\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\"><span data-ogsc=\"\">\u00a0</span></div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\"><span data-ogsc=\"\">Location\u00a0</span>3 Paul Clancy Wy, Worcester, MA 01607</div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\">\u00a0</div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\">Learn more about this initiative here:\u00a0</div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\"><a id=\"OWA150bbdea-a664-46ec-32af-8d4e16da2d08\" class=\"x_OWAAutoLink x_elementToProof\" title=\"https://www.nps.gov/subjects/americanrevolution/revolutionary-war-pension-project.htm\" href=\"https://www.nps.gov/subjects/americanrevolution/revolutionary-war-pension-project.htm\" target=\"_blank\" rel=\"noopener noreferrer\" data-auth=\"NotApplicable\" data-linkindex=\"0\" data-ogsc=\"\">Revolutionary War Pension Project - American Revolution (U.S. National Park Service)</a></div>\n</div>",
#             "location": "3 Paul Clancy Way, Worcester, MA",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "America's Tapestry Project at Old Slater Mill",
#             "description": "<div data-ogsc=\"black\" data-olk-copy-source=\"MessageBody\">As part of the America\u2019s Tapestry Project, Rhode Island's panel is traveling across the state to reach as many hands as possible - no embroidery experience needed!</div>\n<div data-ogsc=\"black\">\u00a0</div>\n<div data-ogsc=\"black\">The tapestry will be at Old Slater Mill in November. Slater Mill is open 10 AM - 4 PM on Fridays and Saturdays.</div>\n<div data-ogsc=\"black\">Drop in anytime, starting November 8, 2025. The tapestry will be onsite until November 29, 2025.</div>\n<div data-ogsc=\"black\">\u00a0</div>\n<div data-ogsc=\"black\">If you want to book a tapestry session for a group, we will have additional dates open. Please reach out to Allison Horrocks: Allison_Horrocks@nps.gov.</div>\n<div data-ogsc=\"black\">\u00a0</div>\n<div data-ogsc=\"black\">More about this project: In 2026, Americans will celebrate our country's 250th anniversary. To commemorate this occasion, America's Tapestry weaves together stories from our nation's founding through the medium of embroidery. The finished 13-panel collection will debut nationally in Williamsburg, VA, in June 2026.</div>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Revolutionary War Pension Files Transcription Event",
#             "description": "<p>In celebration of the 250th anniversary of American independence, the National Archives and the National Park Service are collaborating on a special project to transcribe Revolutionary War Pension Files of more than 80,000 of America's first veterans and their windows, containing more than 2 million documents. These records may contain valuable details about Revolutionary War veterans and their families, such as rank, unit, period of service, age, residence, date and place of marriage, and date and place of death of spouse. You may find copies of marriage or other family records, information pertaining to military activities or details about soldier's lives, along with letters, diaries, or family trees within these records. Become a citizen archivist and unlock the details and stories found within these rich records!</p>\n<p>Blackstone River Valley National Historical Park and the Upton Historical Society will be co-hosting a transcription event on Wednesday, January 14, 2026, from 6-8pm in the\u00a0<strong>Upton Community Center\u00a0</strong>(9 Milford Street, Upton, Massachusetts). Participants will learn about the value of wartime pensions and hear service stories about patriots from the Blackstone Valley. Rangers will provide training on how to access pensions and transcribe these vital records online. Are you ready to join us and contribute to the nation's 250th anniversary?</p>\n<p>Capacity is limited to 25 participants. Participants are asked to bring a laptop or tablet to this event.\u00a0<strong>Please email <a href=\"mailto:blynn@supplychain411.com\">blynn@supplychain411.com </a>if you are interested in attending.</strong></p>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         }
#     ]
# }
#
# --- Output Item 4 ---
# Output type: mcp_call
#
# 🛠️  MCP Tool Call: get_park_events
#    Server: National Parks Service tools
#    ID: call_k33uZDATnvZuyjjPuL4EBhYs
#    Arguments: {"park_code": "rowi", "limit": 10}
# Output:
# {
#     "parkCode": "ROWI",
#     "totalEvents": 2,
#     "events": [
#         {
#             "title": "Roger Williams: The Separation of Church and State",
#             "description": "<p>A cornerstone of our democracy, Roger Williams established a clear limit to government authority. Join a National Park Service ranger as we explore the principles of freedom put into practice by Roger Williams and that changed the course of history.</p>\n<p>The National Park Service is America's largest classroom. These free programs are part of a comprehenisve experience about Roger Williams's contributions to the principles of freedom in America today. Explore your National Memorial today!\u00a0</p>",
#             "location": "The program begins at the historical well",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Roger Williams: The Separation of Church and State",
#             "description": "<p>A cornerstone of our democracy, Roger Williams established a clear limit to government authority. Join a National Park Service ranger as we explore the principles of freedom put into practice by Roger Williams and that changed\u00a0the\u00a0course of history.</p>\n<p>The National Park Service is America's largest classroom. These free programs are part of a comprehenisve experience about Roger Williams's contributions to the principles of freedom in America today. Explore your National Memorial today!\u00a0</p>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         }
#     ]
# }
#
# --- Output Item 5 ---
# Output type: mcp_call
#
# 🛠️  MCP Tool Call: get_park_events
#    Server: National Parks Service tools
#    ID: call_MUuCGQpmWlOPKlCVgf4M6amN
#    Arguments: {"park_code": "tosy", "limit": 10}
# Output:
# {
#     "parkCode": "TOSY",
#     "message": "No upcoming events found for this park"
# }
#
# --- Output Item 6 ---
# Output type: mcp_call
#
# 🛠️  MCP Tool Call: get_park_events
#    Server: National Parks Service tools
#    ID: call_gPdxpIKgDXvfLwcpGT0D5q37
#    Arguments: {"park_code": "waro", "limit": 10}
# Output:
# {
#     "parkCode": "WARO",
#     "message": "No upcoming events found for this park"
# }
#
# --- Output Item 7 ---
# Output type: message
# Response content: Here are some parks in Rhode Island and their upcoming events:
#
# 1. **Blackstone River Valley National Historical Park**
#    - **Description:** This park commemorates how the Blackstone River powered America's entry into the Age of Industry, starting with Samuel Slater's cotton spinning mill.
#    - **Website:** [Blackstone River Valley National Historical Park](https://www.nps.gov/blrv/index.htm)
#    - **Upcoming Events:**
#      - **Old Slater Mill Tours:** Join a Park Ranger for guided tours of the mill. Tours start at 10:30 AM, 12:30 PM, and 2:30 PM.
#      - **Revolutionary War Pension Files Transcription Event:** Join in transcription activities and learn about historical pensions in North Smithfield, RI.
#      - **Archaeology Tours and Events** including walks and open houses at Blackstone River State Park.
#      - **Thematic Walking Tours and Presentations** discussing the history and culture of the mill village.
#
# 2. **Roger Williams National Memorial**
#    - **Description:** This memorial honors Roger Williams and his founding of Providence on principles of religious freedom.
#    - **Website:** [Roger Williams National Memorial](https://www.nps.gov/rowi/index.htm)
#    - **Upcoming Events:**
#      - **Roger Williams: The Separation of Church and State:** Explore the principles of freedom used by Roger Williams with National Park Service rangers.
#
# 3. **Touro Synagogue National Historic Site**
#    - **Description:** An important historical synagogue built in 1763, still active with over 30,000 annual visitors.
#    - **Website:** [Touro Synagogue National Historic Site](https://www.nps.gov/tosy/index.htm)
#    - **Upcoming Events:** No upcoming events were found for this park.
#
# 4. **Washington-Rochambeau Revolutionary Route National Historic Trail**
#    - **Description:** Trails commemorating the march of Rochambeau and his troops alongside George Washington during the Revolutionary War.
#    - **Website:** [Washington-Rochambeau Revolutionary Route](https://www.nps.gov/waro/index.htm)
#    - **Upcoming Events:** No upcoming events were found for this park.
#
# Feel free to check the individual park websites for more detailed information and any updates on events!

# %% [markdown]
# You can see the full output from the call to the Responses API above asking "Tell me about some events at some parks in Rhode Island.".  Here are some of the highlights:
#
# * Output Item 1 shows that it called the NPS server to list all of that server's tools.
# * Output Item 2 shows that it then called the `search_parks` tool from that server with arguments `{"state_code":"RI","limit":5}` and got back a list of 4 national parks in Rhode Island.  Since the limit it specified was 5 and it only got 4, presumably that's all there are in that state.
# * Output Item 3 shows that it called `get_park_events` with arguments `{"park_code": "blrv", "limit": 5}`.  Notice that the value for `park_code` is the same as the value for `code` in the first output from the `search_parks` tool.  So the model recognized that the `code` field in the output of `search_parks` corresponds to the `park_code` field in the input of `get_park_events`.  It gets back a list of events for that park.
# * Output Items 4-6 also call `get_park_events` with the other three park codes that had been returned by the `search_parks` tool.
# * Output Item 7 then provides the actual response to be sent to the user.  It describes the outputs of all four of the calls to `get_park_events` in a human-friendly form.
#
# One important thing to note is that all 7 output items came from *one* call to the Responses API.  This illustrates one of the advantages of this API and its implementation in Llama Stack: Llama Stack handles all of the coordination between all of these steps and calls the model and to the MCP server.  You could accomplish the same thing using basic "completions" API that allow you to specify tools, but it would then be up to you in the client to do all that coordinating.

# %% [markdown]
# ## Using the OpenAI client
#
# In the examples above we used the Llama Stack client to connect to Llama Stack.  However, since we're calling an OpenAI-compatible API (Responses), we can also use the OpenAI client to do the same thing.  The setup is a little bit clunkier than it is using the Llama Stack client.  With the OpenAI client, you have to add some extra stuff at the end of the URL to point the client at the OpenAI-compatible part of the overall Llama Stack.  However, once you do that, you can do the same things with the OpenAI client as we did with the Llama Stack client above.
#
# Using the OpenAI client may be the best fit if you are writing code for a project that already uses that client for other purposes and you don't want to add any more dependencies to that project.
#
# We start with the slightly clunky setup:

# %%
from openai import OpenAI

# Direct OpenAI client instantiation with Llama Stack
openai_client = OpenAI(
    api_key="no-key-needed",  # Llama Stack typically doesn't require a real key
    base_url=LLAMA_STACK_URL + "v1/openai/v1", # This suffix gets to the part of the URL that is specific to the OpenAI API, which you need here since you are using the OpenAI client.
)

# %% [markdown]
# Notice that while this is the OpenAI client, the URL we pointed it to is our Llama Stack server.  So even though we're using a different client here, we're still using the same server to handle the request.  Here we see that the simple example we used above works the same way as it did with the Llama Stack client:

# %%
simple_openai_client_response = openai_client.responses.create(
    model=LLAMA_STACK_MODEL_ID,
    input="What is the capital of France?"
)

print_response(simple_openai_client_response)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/openai/v1/responses "HTTP/1.1 200 OK"
# ID: resp-712df407-0774-432c-a8d5-1523bdb85641
# Status: completed
# Model: openai/gpt-4o
# Created at: 1759432075.0
# Output items: 1
# Output type: message
# Response content: The capital of France is Paris.

# %% [markdown]
# The RAG example also works the same way it did with the Llama Stack client:

# %%
import uuid

openai_client_vector_store_name= f"vec_{str(uuid.uuid4())[0:8]}"

openai_client_vector_store = openai_client.vector_stores.create(name=vector_store_name)
openai_client_vector_store_id = vector_store.id

openai_client_vector_store_id
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/openai/v1/vector_stores "HTTP/1.1 200 OK"
# 'vs_8715bef2-0dee-4d0a-9047-6cbd8795590f'

# %%
openai_client_file_create_response = openai_client.files.create(file=Path(pdf_path), purpose="assistants")
#openai_client_file_create_response
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/openai/v1/files "HTTP/1.1 200 OK"

# %%
openai_client_file_ingest_response = openai_client.vector_stores.files.create(
    vector_store_id=vector_store_id,
    file_id=file_create_response.id,
)
#openai_client_file_ingest_response
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/openai/v1/vector_stores/vs_8715bef2-0dee-4d0a-9047-6cbd8795590f/files "HTTP/1.1 200 OK"

# %%
rag_openai_client_response = openai_client.responses.create(
    model=LLAMA_STACK_MODEL_ID,
    input="When did the Bering Land Bridge become a national preserve?",
    tools=[
        {
            "type": "file_search",
            "vector_store_ids": [vector_store_id],
        }
    ]
)

print_response(rag_openai_client_response)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/openai/v1/responses "HTTP/1.1 200 OK"
# ID: resp-fd344bb9-3ada-4812-baf6-f0db69c06082
# Status: completed
# Model: openai/gpt-4o
# Created at: 1759432104.0
# Output items: 2
#
# --- Output Item 1 ---
# Output type: file_search_call
#   Tool Call ID: call_HSWIynSVH6GfhnkHjcVhHEZc
#   Tool Status: completed
#   Queries: Bering Land Bridge national preserve establishment date
#   Results: [Result(attributes={}, file_id='', filename='', score=3.207261619387233, text=' for abundant wildlife and sport\n \nfishing for five species of salmon.\n \nEstablished Dec. 2, 1980. Length: 67 miles.\n \nAcreage—30,664.79 Federal: 26,417.85 \nNonfederal: 4,246.94. \nAniakchak  \nN\national Monument  and \nAniakchak  \nNational Preserve \n1000 Silver Street, Bldg.603 \nP\nO Box 245 \nKing Salmon, AK 99613 \n907\xad246\xad3305 \nwww.nps.gov/ania \nThe Aniakchak Caldera, covering some 30 square miles, is \no\nne of the great dry calderas in the world. Located in the \nvolcanically active Aleutian Mountains, the Aniakchak last \nerupted in
#
# --- Output Item 2 ---
# Output type: message
# Response content: The Bering Land Bridge was established as a national preserve on December 2, 1980.

# %% [markdown]
# And similarly, the complex example using the NPS MCP server also works the same way as it did with the Llama Stack client:

# %%
complex_openai_client_response = openai_client.responses.create(
    model=LLAMA_STACK_MODEL_ID,
    input="Tell me about some parks in Rhode Island, and let me know if there are any upcoming events at them.",
    tools=[
        {
            "type": "mcp",
            "server_url": NPS_MCP_URL,
            "server_label": "National Parks Service tools",
        }
    ]
)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/openai/v1/responses "HTTP/1.1 200 OK"

# %% [markdown]
# Because both the OpenAI client and the Llama Stack client are wrapping the same underlying server API, the structures of their outputs wind up being the same too, so the complicated print_response method that prints out the response objects for the Llama Stack client also prints out the response objects for the OpenAI client.

# %%
print_response(complex_openai_client_response)
# Out:
# ID: resp-8c7e0486-631f-428c-8b10-1f970bb3038e
# Status: completed
# Model: openai/gpt-4o
# Created at: 1759432111.0
# Output items: 7
#
# --- Output Item 1 ---
# Output type: mcp_list_tools
#
# 🔧 MCP Server: National Parks Service tools
#    ID: mcp_list_0f2962b4-8f4b-453f-bd4f-b126c5479eff
#    Available Tools: 5
# ================================================================================
#
# 1. search_parks
#    Description: Search for national parks by state, park code, or query string.
#
# Args:
#     state_code: Two-letter state code (e.g., 'CA', 'NY')
#     park_code: Four-letter park code (e.g., 'yell', 'acad')
#     query: Search query for park names or descriptions
#     limit: Maximum number of results to return (default: 10)
#
# Returns:
#     JSON string with park information including name, description, website, and location
#    Parameters:
#      • state_code (string) (required)
#      • park_code (string) (required)
#      • query (string) (required)
#      • limit (integer) (required)
# ----------------------------------------
#
# 2. get_park_alerts
#    Description: Get current alerts for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#
# Returns:
#     JSON string with current alerts for the park
#    Parameters:
#      • park_code (string) (required)
# ----------------------------------------
#
# 3. get_park_campgrounds
#    Description: Get campground information for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of campgrounds to return (default: 10)
#
# Returns:
#     JSON string with campground information including location, amenities, and fees
#    Parameters:
#      • park_code (string) (required)
#      • limit (integer) (required)
# ----------------------------------------
#
# 4. get_park_events
#    Description: Get upcoming events for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of events to return (default: 10)
#
# Returns:
#     JSON string with event information including date, time, fee, and description
#    Parameters:
#      • park_code (string) (required)
#      • limit (integer) (required)
# ----------------------------------------
#
# 5. get_visitor_centers
#    Description: Get visitor center information for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of visitor centers to return (default: 10)
#
# Returns:
#     JSON string with visitor center information including location, contact, and operating hours
#    Parameters:
#      • park_code (string) (required)
#      • limit (integer) (required)
#
# --- Output Item 2 ---
# Output type: mcp_call
#
# 🛠️  MCP Tool Call: search_parks
#    Server: National Parks Service tools
#    ID: call_BG8kPvMVDjp30KKFNxvoqMKa
#    Arguments: {"state_code":"RI","limit":5}
# Output:
# {
#     "total": "4",
#     "parks": [
#         {
#             "name": "Blackstone River Valley National Historical Park",
#             "code": "blrv",
#             "description": "The Blackstone River powered America's entry into the Age of Industry. The success of Samuel Slater's cotton spinning mill in Pawtucket, RI touched off a chain reaction that changed how people worked and where they lived. Learn how this revolution transformed the landscape of the Blackstone Valley and the United States. The Visitor Center at Old Slater Mill is currently open Thursday-Sunday, 10-4.",
#             "website": "https://www.nps.gov/blrv/index.htm",
#             "states": "RI,MA",
#             "designation": "National Historical Park",
#             "latitude": "41.8775792792",
#             "longitude": "-71.382433945"
#         },
#         {
#             "name": "Roger Williams National Memorial",
#             "code": "rowi",
#             "description": "\"I acknowledge that to molest any person, Jew or Gentile, for either professing doctrine, or practicing worship meerly religious or spiritual, is to persecute him, and such a person (whether his doctrine or practice be true or false) suffers persecution for conscience.\" -Roger Williams, 1644 Banished by the English and saved by the First Peoples, Roger Williams founded Providence here in 1636.",
#             "website": "https://www.nps.gov/rowi/index.htm",
#             "states": "RI",
#             "designation": "National Memorial",
#             "latitude": "41.8298955",
#             "longitude": "-71.41056665"
#         },
#         {
#             "name": "Touro Synagogue National Historic Site",
#             "code": "tosy",
#             "description": "Touro Synagogue, a building of exquisite beauty and design, steeped in history and ideals, and one of the most historically significant Jewish buildings in America, was designated a National Historic Site in 1946. Dedicated in 1763, it still serves an active congregation and each year greets over 30,000 visitors who come to see the magnificent interior and hear its remarkable story.",
#             "website": "https://www.nps.gov/tosy/index.htm",
#             "states": "RI",
#             "designation": "National Historic Site",
#             "latitude": "41.4893",
#             "longitude": "-71.3121"
#         },
#         {
#             "name": "Washington-Rochambeau Revolutionary Route National Historic Trail",
#             "code": "waro",
#             "description": "\u201cOf the happiness I have enjoyed in our private friendship. The remembrance of which will be one of the most pleasing Circumstances of my life.\u201d\u2013 Comte de Rochambeau on his relationship with George Washington",
#             "website": "https://www.nps.gov/waro/index.htm",
#             "states": "MA,RI,CT,NY,NJ,PA,DE,MD,VA,DC",
#             "designation": "National Historic Trail",
#             "latitude": "40.0958204557",
#             "longitude": "-74.8563515109"
#         }
#     ]
# }
#
# --- Output Item 3 ---
# Output type: mcp_call
#
# 🛠️  MCP Tool Call: get_park_events
#    Server: National Parks Service tools
#    ID: call_ajz454IAtpxFoEvQx4wadgWt
#    Arguments: {"park_code": "blrv", "limit": 5}
# Output:
# {
#     "parkCode": "BLRV",
#     "totalEvents": 14,
#     "events": [
#         {
#             "title": "Old Slater Mill Tour",
#             "description": "<p>Join a Park Ranger on a tour of the Mill that started the American Industrial Revolution. These 30 minute guided tours investigate the historical significance of Slater Mill, and what valuable lessons the building still teachings us. Tours begin at 10:30 AM, 12:30 PM and 2:30 PM in front of the mill. Please arrive a few minutes early.</p>\n<p>\u00a0</p>\n<p><u><em>Please Note:</em></u><em>\u00a0</em><em>For visitor saftey, tours of Old Slater Mill will be modified or cancelled if the heat index is at or above 87 degrees Fahrenheit. A shortened 10 minute Ranger talk will be offered at the normal tour times. Visitors will have a brief period of access to the main part of the mill. For the latest weather information, call 401-725-8638.</em></p>",
#             "location": "67 Roosevelt Avenue, Pawtucket, RI 02860",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Old Slater Mill Tour",
#             "description": "<p>Join a Park Ranger on a tour of the Mill that started the American Industrial Revolution. These 30 minute guided tours investigate the historical significance of Slater Mill, and what valuable lessons the building still teachings us. Tours begin at 10:30 AM, 12:30 PM and 2:30 PM in front of the mill. Please arrive a few minutes early.</p>\n<p>\u00a0</p>\n<p><u><em>Please Note:</em></u><em>\u00a0</em><em>For visitor saftey, tours of Old Slater Mill will be modified or cancelled if the heat index is at or above 87 degrees Fahrenheit. A shortened 10 minute Ranger talk will be offered at the normal tour times. Visitors will have a brief period of access to the main part of the mill. For the latest weather information, call 401-725-8638.</em></p>",
#             "location": "67 Roosevelt Avenue, Pawtucket, RI 02860",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Revolutionary War Pension Files Transcription Event",
#             "description": "<p>Be a Citizen Archivist!</p>\n<p>Join Blackstone River Valley National Historical Park and North Smithfield Heritage Association for a series of free evening programs this fall. Hosted from 6-7:30 PM at Heritage Hall, 101 Greene St., North Smithfield, RI. Open to all, no registration is required.\u00a0</p>\n<p>Participants will learn about the value of pensions from the War for Independence. Rangers will talk about these sources and teach participants how to transcribe records (available online) from the National Archives. Participants are encouraged to bring a laptop or tablet for typing records. WiFi will be available for all.\u00a0</p>\n<p>DATES: October 1, November 5, and December 3, 2025</p>",
#             "location": "Meet in Heritage Hall, located at 101 Greene St., North Smithfield, RI.",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Blackstone River State Park Archaeology Tour",
#             "description": "<p>Enjoy a guided walk around\u00a0Blackstone\u00a0River State Park during Archaeology Month.\u00a0Learn how\u00a0archaeologists\u00a0have\u00a0uncovered the history of this\u00a0site.\u00a0</p>\n<p>This walk will cover some uneven terrain.</p>\n<p>Meet at\u00a01075 Lower River Road, Lincoln, RI.</p>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Voting in Our Mill Village",
#             "description": "<div class=\"x_elementToProof\">\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\"><span data-ogsc=\"\" data-olk-copy-source=\"MessageBody\">Allison Horrocks, Park Ranger at the Blackstone River Valley National Historical Park will take us back in time with a fascinating presentation of the \"how\" and \"who\" of voting in our mill villages.</span></div>\n</div>\n<div class=\"x_elementToProof\">\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\"><span data-ogsc=\"\">This presentation is part of a series events hosted by the\u00a0</span><span data-ogsc=\"\">Douglas Historical Society, a 2025-2026 Host Site for the Smithsonian Institution\u2019s Museum On Main Street\u2019s exhibit\u00a0<em data-ogsc=\"\">Voices and Votes: Democracy in America</em>. Since 1994, the Smithsonian has brought 13 different exhibits to over 1900 communities through Museum on Main Street, a part of the Smithsonian Institution Traveling Exhibition Service. Museum on Main Street is the means for the Smithsonian Institute to provide small-town America access to various museum exhibitions, research, educational resources and programming with ready-to-install exhibitions.</span></div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\"><span data-ogsc=\"\">Completed in 2000,\u00a0<em data-ogsc=\"\">Voices and Votes: Democracy in America</em>\u00a0is based on the Smithsonian\u2019s National Museum of American History permanent exhibit,\u00a0<em data-ogsc=\"\">American Democracy: A Great Leap of Faith</em>. Learn more here:\u00a0</span><span data-ogsc=\"\"><a id=\"OWA5ee1b3a0-266e-1102-39c7-c4239e17c1ef\" class=\"x_OWAAutoLink x_elementToProof\" title=\"Original URL: https://mysfpl.org/moms/. Click or tap if you trust this link.\" href=\"https://gcc02.safelinks.protection.outlook.com/?url=https%3A%2F%2Fmysfpl.org%2Fmoms%2F&amp;data=05%7C02%7CMark_Mello%40nps.gov%7C5f204d83bdd445daa54908ddfd196d31%7C0693b5ba4b184d7b9341f32f400a5494%7C0%7C0%7C638945007821407099%7CUnknown%7CTWFpbGZsb3d8eyJFbXB0eU1hcGkiOnRydWUsIlYiOiIwLjAuMDAwMCIsIlAiOiJXaW4zMiIsIkFOIjoiTWFpbCIsIldUIjoyfQ%3D%3D%7C0%7C%7C%7C&amp;sdata=AkJ9E5gaiYDxPvOhS78D5UIoooulRKfN9qquuHtrmUc%3D&amp;reserved=0\" target=\"_blank\" rel=\"noopener noreferrer\" data-auth=\"NotApplicable\" data-linkindex=\"1\" data-ogsc=\"\">Voices &amp; Votes: Democracy in America \u2013 Simon Fairfield Public Library</a>.\u00a0</span></div>\n</div>",
#             "location": "E.N. Jenckes Store Museum, 283 Main St, Douglas, MA 01516, USA",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "1670: The Jenks Settlement Walking Tour",
#             "description": "<div data-ogsc=\"black\"><em data-ogsc=\"\" data-olk-copy-source=\"MessageBody\">Presented by Old Slater Mill Association</em></div>\n<div data-ogsc=\"black\">\u00a0</div>\n<div data-ogsc=\"black\">Join interpreter Joshua\u00a0Choiniere\u202fof the Old Slater Mill Association\u00a0for a walking tour\u00a0of the original settlement of Pawtucket Village by Joseph Jenks Jr.\u00a0This tour will extend all the way up to Bayley Street.\u00a0This program will cover approximately one mile on\u00a0paved surface, with some small hills and steps. Meet in front of Sylvanus Brown House on the Old Slater Mill campus.\u202f\u00a0</div>\n<div id=\"x_Signature\">\u00a0</div>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "I Dig Slater Mill Open House",
#             "description": "<p>Experience Archaeology Month at Blackstone River Valley National Historical Park!\u202f\u00a0</p>\n<p>Learn about the archaeological digs that have taken place at Old Slater Mill and see artifacts courtesy of the Slater Industrial Archives.\u202fWatch footage of archaeologists working on the site, try hands-on activities, and conduct a search for small\u202ftreasures.\u202f \u00a0</p>\n<p>In addition to drop-in offerings, mill tours will be available at 10:30 AM., 12:30 PM., and 2:30 PM, free of charge.\u202f</p>\n<p>Visitors may also take part in a walking tour about the Pawtucket Village settlement. This walk will be led by Joshua Choiniere on Saturday, October 12, 2024, at 11:30 AM. \u00a0</p>\n<p>Presented in partnership with the Old Slater Mill Association.\u00a0</p>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Of Factories and Fiction: Gothic Tales at Slater Mill",
#             "description": "<p><span data-olk-copy-source=\"MessageBody\">The early decades of the industrial revolution gave rise to new and occasionally frightening forms of technology--this was evident in factories, but there were also changes in fiction. The Gothic novel, after all, was \"invented\" in the same year as the spinning jenny. These innovations set the stage for the development of harrowing tales about mills. During this program, visitors will learn about the history of Slater Mill through readings of historical poems, snippets from Samuel Slater's autobiography, and other primary sources.\u00a0</span></p>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Webster Walking Tour",
#             "description": "<p><span data-olk-copy-source=\"MessageBody\">Join Allison Horrocks from the National Park Service for a historic walking tour of downtown Webster. Whether you\u2019re a lifelong resident, new to the area, or just visiting for the day, you\u2019re sure to learn something new! </span></p>\n<p><span data-olk-copy-source=\"MessageBody\">This event is for all ages, and participants will meet in the lobby of the Gladys E. Kelly Public Library before the guided tour.\u00a0</span></p>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Bat Walk",
#             "description": "<p>Mark your calendars for a special Night Sky Program, featuring a Bat Walk!<br /><br />Celebrate the beginning of Bat Week on Friday, October 24, 2025, by attending this special evening event at River Bend Farm. Explore everything the night sky has to offer and get a closer view of the stars, the moon, and our neighboring planets through a telescope. For stargazing, meet in the field across from the River Bend Farm Visitor Center.<br /><br />Doors will open for Bat Week crafts and activities at 6 PM. Night Sky runs from 6:30-8:00 PM.<br /><br />All programs are free and open to the public. Registration is not required. Appropriate for all ages. All children must be accompanied by an adult. Dress for the weather. Bringing bug spray is encouraged. For the most up to date programming information, call (508) 278-7604 or visit us at\u00a0<a id=\"OWAfacdc0fc-b42e-33d7-5f4a-ed8995912f84\" class=\"x_x1fey0fg x_xmper1u x_x1edh9d7 x_OWAAutoLink x_elementToProof\" title=\"Original URL: https://bit.ly/blstupdates. Click or tap if you trust this link.\" href=\"https://gcc02.safelinks.protection.outlook.com/?url=https%3A%2F%2Fbit.ly%2Fblstupdates&amp;data=05%7C02%7CMark_Mello%40nps.gov%7C01ebe5d0efa24eec11c908ddfd08bcc9%7C0693b5ba4b184d7b9341f32f400a5494%7C0%7C0%7C638944936342132582%7CUnknown%7CTWFpbGZsb3d8eyJFbXB0eU1hcGkiOnRydWUsIlYiOiIwLjAuMDAwMCIsIlAiOiJXaW4zMiIsIkFOIjoiTWFpbCIsIldUIjoyfQ%3D%3D%7C0%7C%7C%7C&amp;sdata=PsiWUwPWfUgAo9vKKX0XuioY%2Bi4%2BptE77vgBeI%2Fxlso%3D&amp;reserved=0\" target=\"_blank\" rel=\"noopener noreferrer\" data-auth=\"NotApplicable\" data-linkindex=\"0\" data-ogsc=\"\">bit.ly/blstupdates</a></p>",
#             "location": "287 Oak Street, Uxbridge, MA",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Hopedale Walking Tour",
#             "description": "<div data-ogsc=\"black\" data-ogsb=\"white\" data-olk-copy-source=\"MessageBody\">Step back in time and explore Hopedale as it was in 1888. Hopedale has been home to many different types of workers. Hear about the various occupations that have pushed or pulled people towards Hopedale during this guided ranger tour.\u00a0</div>\n<div data-ogsc=\"black\" data-ogsb=\"white\" data-olk-copy-source=\"MessageBody\">\u00a0</div>\n<div data-ogsc=\"black\" data-ogsb=\"white\" data-olk-copy-source=\"MessageBody\">Tour begins at 43 Hope Street, Hopedale, MA.\u00a0</div>\n<div data-ogsc=\"black\" data-ogsb=\"white\">\u00a0</div>\n<div data-ogsc=\"black\" data-ogsb=\"white\">More about this series:\u00a0</div>\n<div data-ogsc=\"black\" data-ogsb=\"white\">This tour will last approximately 1 hour.\u00a0</div>\n<div data-ogsc=\"black\" data-ogsb=\"white\">\u00a0</div>\n<div data-ogsb=\"white\"><span data-ogsc=\"black\">Join a Park Ranger as we explore park sites and local communities this Fall. Tours will discuss the history of each site and its importance within the larger context of US history. Tours last about 60-90 minutes. Walking moderate distances on sometimes uneven terrain should be expected. Sturdy footwear, comfortable clothing, and water are suggested. </span></div>\n<div data-ogsb=\"white\">\u00a0</div>\n<div data-ogsb=\"white\"><span data-ogsc=\"black\">I</span><span data-ogsc=\"black\">f you have questions about accessibility, please contact Ranger\u00a0</span><span data-ogsc=\"rgb(14, 111, 163)\"><a id=\"OWA1f7e4a43-43a0-1739-74a2-6c9d9d6a57fc\" title=\"mailto:allison_horrocks@nps.gov\" href=\"mailto:allison_horrocks@nps.gov\" data-linkindex=\"5\" data-ogsc=\"rgb(14, 111, 163)\">Allison Horrocks</a></span><span data-ogsc=\"black\">.</span></div>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Revolutionary War Pension Files Transcription Even",
#             "description": "<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\" data-olk-copy-source=\"MessageBody\">Be a Citizen Archivist!</div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\">Join Blackstone River Valley National Historical Park on a quest to transcribe the pension records of local Revolutionary War veterans and widows.\u00a0</div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\">Long after their period of service had ended, veterans from the War for Independence sought recognition and compensation from their government. During this program, participants will explore the value of early pension records from America\u2019s first veterans and their widows. Participants will also learn how to transcribe these records as part of a joint initiative between the National Park Service and the National Archives and Records Administration (NARA), just in time for the 250th anniversary of the American Revolution.\u00a0</div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\">Participants\u00a0are encouraged to bring a laptop or tablet for typing records. WiFi will be available.\u00a0\u00a0</div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\">Hosted with the Massachusetts Department of Conservation &amp; Recreation (MA DCR) at Blackstone Heritage Corridor Visitor Center at Worcester. Open to all, no registration is required.\u00a0</div>\n<div id=\"x_Signature\" class=\"x_elementToProof\">\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\"><span data-ogsc=\"\">\u00a0</span></div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\"><span data-ogsc=\"\">Location\u00a0</span>3 Paul Clancy Wy, Worcester, MA 01607</div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\">\u00a0</div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\">Learn more about this initiative here:\u00a0</div>\n<div class=\"x_elementToProof\" data-ogsc=\"rgb(0, 0, 0)\"><a id=\"OWA150bbdea-a664-46ec-32af-8d4e16da2d08\" class=\"x_OWAAutoLink x_elementToProof\" title=\"https://www.nps.gov/subjects/americanrevolution/revolutionary-war-pension-project.htm\" href=\"https://www.nps.gov/subjects/americanrevolution/revolutionary-war-pension-project.htm\" target=\"_blank\" rel=\"noopener noreferrer\" data-auth=\"NotApplicable\" data-linkindex=\"0\" data-ogsc=\"\">Revolutionary War Pension Project - American Revolution (U.S. National Park Service)</a></div>\n</div>",
#             "location": "3 Paul Clancy Way, Worcester, MA",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "America's Tapestry Project at Old Slater Mill",
#             "description": "<div data-ogsc=\"black\" data-olk-copy-source=\"MessageBody\">As part of the America\u2019s Tapestry Project, Rhode Island's panel is traveling across the state to reach as many hands as possible - no embroidery experience needed!</div>\n<div data-ogsc=\"black\">\u00a0</div>\n<div data-ogsc=\"black\">The tapestry will be at Old Slater Mill in November. Slater Mill is open 10 AM - 4 PM on Fridays and Saturdays.</div>\n<div data-ogsc=\"black\">Drop in anytime, starting November 8, 2025. The tapestry will be onsite until November 29, 2025.</div>\n<div data-ogsc=\"black\">\u00a0</div>\n<div data-ogsc=\"black\">If you want to book a tapestry session for a group, we will have additional dates open. Please reach out to Allison Horrocks: Allison_Horrocks@nps.gov.</div>\n<div data-ogsc=\"black\">\u00a0</div>\n<div data-ogsc=\"black\">More about this project: In 2026, Americans will celebrate our country's 250th anniversary. To commemorate this occasion, America's Tapestry weaves together stories from our nation's founding through the medium of embroidery. The finished 13-panel collection will debut nationally in Williamsburg, VA, in June 2026.</div>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Revolutionary War Pension Files Transcription Event",
#             "description": "<p>In celebration of the 250th anniversary of American independence, the National Archives and the National Park Service are collaborating on a special project to transcribe Revolutionary War Pension Files of more than 80,000 of America's first veterans and their windows, containing more than 2 million documents. These records may contain valuable details about Revolutionary War veterans and their families, such as rank, unit, period of service, age, residence, date and place of marriage, and date and place of death of spouse. You may find copies of marriage or other family records, information pertaining to military activities or details about soldier's lives, along with letters, diaries, or family trees within these records. Become a citizen archivist and unlock the details and stories found within these rich records!</p>\n<p>Blackstone River Valley National Historical Park and the Upton Historical Society will be co-hosting a transcription event on Wednesday, January 14, 2026, from 6-8pm in the\u00a0<strong>Upton Community Center\u00a0</strong>(9 Milford Street, Upton, Massachusetts). Participants will learn about the value of wartime pensions and hear service stories about patriots from the Blackstone Valley. Rangers will provide training on how to access pensions and transcribe these vital records online. Are you ready to join us and contribute to the nation's 250th anniversary?</p>\n<p>Capacity is limited to 25 participants. Participants are asked to bring a laptop or tablet to this event.\u00a0<strong>Please email <a href=\"mailto:blynn@supplychain411.com\">blynn@supplychain411.com </a>if you are interested in attending.</strong></p>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         }
#     ]
# }
#
# --- Output Item 4 ---
# Output type: mcp_call
#
# 🛠️  MCP Tool Call: get_park_events
#    Server: National Parks Service tools
#    ID: call_2BeT7CXe8hnhuNp0I2BmNSGn
#    Arguments: {"park_code": "rowi", "limit": 5}
# Output:
# {
#     "parkCode": "ROWI",
#     "totalEvents": 2,
#     "events": [
#         {
#             "title": "Roger Williams: The Separation of Church and State",
#             "description": "<p>A cornerstone of our democracy, Roger Williams established a clear limit to government authority. Join a National Park Service ranger as we explore the principles of freedom put into practice by Roger Williams and that changed the course of history.</p>\n<p>The National Park Service is America's largest classroom. These free programs are part of a comprehenisve experience about Roger Williams's contributions to the principles of freedom in America today. Explore your National Memorial today!\u00a0</p>",
#             "location": "The program begins at the historical well",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Roger Williams: The Separation of Church and State",
#             "description": "<p>A cornerstone of our democracy, Roger Williams established a clear limit to government authority. Join a National Park Service ranger as we explore the principles of freedom put into practice by Roger Williams and that changed\u00a0the\u00a0course of history.</p>\n<p>The National Park Service is America's largest classroom. These free programs are part of a comprehenisve experience about Roger Williams's contributions to the principles of freedom in America today. Explore your National Memorial today!\u00a0</p>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         }
#     ]
# }
#
# --- Output Item 5 ---
# Output type: mcp_call
#
# 🛠️  MCP Tool Call: get_park_events
#    Server: National Parks Service tools
#    ID: call_ILx8qSJDBxO5I12icf9XpBuf
#    Arguments: {"park_code": "tosy", "limit": 5}
# Output:
# {
#     "parkCode": "TOSY",
#     "message": "No upcoming events found for this park"
# }
#
# --- Output Item 6 ---
# Output type: mcp_call
#
# 🛠️  MCP Tool Call: get_park_events
#    Server: National Parks Service tools
#    ID: call_3hS5g5vGWjqkuwyVUqTqyESo
#    Arguments: {"park_code": "waro", "limit": 5}
# Output:
# {
#     "parkCode": "WARO",
#     "message": "No upcoming events found for this park"
# }
#
# --- Output Item 7 ---
# Output type: message
# Response content: Here are some national parks in Rhode Island and their upcoming events:
#
# 1. **Blackstone River Valley National Historical Park**:
#    - **Description**: The Blackstone River powered America's entry into the Age of Industry. Discover the landscape transformation and the industrial revolution's impact.
#    - **Website**: [Blackstone River Valley NHP](https://www.nps.gov/blrv/index.htm)
#
#    **Upcoming Events**:
#    - **Old Slater Mill Tour**: Join a Park Ranger for a 30-minute guided tour exploring the historical significance of Slater Mill, held multiple times daily.
#    - **Revolutionary War Pension Files Transcription Event**: Participate in a citizen archivist activity at various times this fall at Heritage Hall, North Smithfield, RI.
#    - **Archaeology Month events**: Includes tours, open houses, and discussions at the Mill exploring archaeology and history in October.
#    - **America's Tapestry Project**: Contribute to this nationwide embroidery project visiting Slater Mill from November 8-29, 2025.
#
# 2. **Roger Williams National Memorial**:
#    - **Description**: This memorial honors Roger Williams, founder of Providence, who advocated for religious freedom and the separation of church and state.
#    - **Website**: [Roger Williams NM](https://www.nps.gov/rowi/index.htm)
#
#    **Upcoming Events**:
#    - **Roger Williams: The Separation of Church and State**: Join a ranger to explore the democracy principles established by Roger Williams. These talks highlight his impact on American freedom.
#
# 3. **Touro Synagogue National Historic Site**:
#    - **Description**: This is one of America's most historically significant Jewish buildings, dating back to 1763.
#    - **Website**: [Touro Synagogue NHS](https://www.nps.gov/tosy/index.htm)
#    - **Events**: Currently, no upcoming events are listed.
#
# 4. **Washington-Rochambeau Revolutionary Route National Historic Trail**:
#    - **Description**: This trail follows the historic route taken during the Revolutionary War by allied American and French troops.
#    - **Website**: [Washington-Rochambeau NHT](https://www.nps.gov/waro/index.htm)
#    - **Events**: Currently, no upcoming events are listed.
#
# These parks offer a range of historical and educational experiences, and you can plan visits around the events that interest you!

# %% [markdown]
# As you can see, we get the same results here that we did with the Llama Stack client, as you would expect since we're calling the same Llama Stack server with the same arguments.

# %% [markdown]
# ## LangChain
#
# Both of the examples above are using clients that directly mirror the Responses API.  That means you have complete control over and visibility into exactly what's going into the API and exactly what's coming out of the API.  That can be useful and powerful, but it can also be a little complicated and tedious.  A lot of users prefer to use a framework that provides higher level abstractions.  Examples of such frameworks include LangChain, LangGraph, LlamaIndex, Haystack, and many more.
#
# Here we configure LangChain with `use_responses_api` so it will use the same Responses API that we use above.  However, it hides a lot of the details of that API making the code simpler.

# %%
from langchain_openai import ChatOpenAI

# Pointing to your local Responses API server
llm = ChatOpenAI(
    model=LLAMA_STACK_MODEL_ID,
    base_url=LLAMA_STACK_URL + "v1/openai/v1", # This suffix gets to the part of the URL that is specific to the OpenAI API, which you need here since you are using the OpenAI client.,
    use_responses_api=True
)

# %%
import json

def simple_print(obj) -> None:
    if hasattr(obj, "__dict__"):
        print(json.dumps(obj.__dict__, indent=2, default=str))
    else:
        print(json.dumps(obj, indent=2, default=str))

# %%
langchain_simple_response = llm.invoke("What is the capital of France?")
simple_print(langchain_simple_response)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/openai/v1/responses "HTTP/1.1 200 OK"
# {
#   "content": [
#     {
#       "type": "text",
#       "text": "The capital of France is Paris.",
#       "annotations": []
#     }
#   ],
#   "additional_kwargs": {},
#   "response_metadata": {
#     "id": "resp-5901b3c0-bd56-4d58-920a-1d1e54269f88",
#     "created_at": 1759432144.0,
#     "model": "openai/gpt-4o",
#     "object": "response",
#     "status": "completed",
#     "model_name": "openai/gpt-4o"
#   },
#   "type": "ai",
#   "name": null,
#   "id": "msg_ea22c39a-0c85-41f7-ae07-dd45c9c33dcf",
#   "example": false,
#   "tool_calls": [],
#   "invalid_tool_calls": [],
#   "usage_metadata": null
# }

# %% [markdown]
# We can then use the vector store that we populated earlier to do basic RAG answering:

# %%
llm_with_rag = llm.bind_tools([
  {
    "type": "file_search",
    "vector_store_ids": [vector_store_id],
  },
])

langchain_rag_response = llm_with_rag.invoke("When did the Bering Land Bridge become a national preserve?")
simple_print(langchain_rag_response)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/openai/v1/responses "HTTP/1.1 200 OK"
# {
#   "content": [
#     {
#       "type": "text",
#       "text": "The Bering Land Bridge was established as a national preserve on December 2, 1980.",
#       "annotations": []
#     }
#   ],
#   "additional_kwargs": {
#     "tool_outputs": [
#       {
#         "id": "call_Anq8xC5VMmUiKsZMOxUBiPLg",
#         "queries": [
#           "Bering Land Bridge national preserve designation date"
#         ],
#         "status": "completed",
#         "type": "file_search_call",
#         "results": [
#           {
#             "attributes": {},
#             "file_id": "",
#             "filename": "",
#             "score": 3.0400664069376475,
#             "text": " for abundant wildlife and sport\n \nfishing for five species of salmon.\n \nEstablished Dec. 2, 1980. Length: 67 miles.\n \nAcreage\u201430,664.79 Federal: 26,417.85 \nNonfederal: 4,246.94. \nAniakchak  \nN\national Monument  and \nAniakchak  \nNational Preserve \n1000 Silver Street, Bldg.603 \nP\nO Box 245 \nKing Salmon, AK 99613 \n907\u00ad246\u00ad3305 \nwww.nps.gov/ania \nThe Aniakchak Caldera, covering some 30 square miles, is \no\nne of the great dry calderas in the world. Located in the \nvolcanically active Aleutian Mountains, the Aniakchak last \nerupted in 1931. The crater includes lava flows, cinder cones, \nand explosion pits, as well as Surprise Lake, source of the \nAniakchak River, which cascades through a 1,500\u00adfoot gash \nin the crater wall. NO FEDERAL FACILITIES. \nProclaimed Aniakchak National Monument Dec. 1, 1978; \nestablished as a national monument and national preserve \nDec. 2, 1980. \nAcreage\u2014National monument: 137,176.00, all Federal. \nNational preserve: 464,117.93 Federal: 458,809.35 \nNonfederal: 5,308.58. \nBering Land Bridge \nN\national Preserve \nPO Box 220 \nN\nome, AK\u00a099762\u00ad0220 \n907\u00ad443\u00ad2522 \nwww.nps.gov/bela \nLocated on the Seward Peninsula, the preserve is a remnant \no\nf the land bridge that once connected Asia with North \nAmerica over 13,000 years ago. Paleontological and archeo\u00ad\nlogical resources abound; large populations of migratory \nbirds nest here. Ash explosion craters and lava flows, rare in \nthe Arctic, are present. LIMITED FEDERAL FACILITIES. \nProclaimed a national monument Dec. 1, 1978; established as \na national preserve Dec. 2, 1980. \nAcreage\u20142,697,391.01 Federal: 2,632,508.00 \nNonfederal: 64,883.01 \nCape Krusenstern \nN\national Monument \nPO Box 1029 \nK\notzebue, AK 99752\u00ad0029 \n907\u00ad442\u00ad3890 \nwww.nps.gov/cakr \nArcheological sites located along a succession of 114 lateral \nbeac\nh ridges illustrate Eskimo communities of every known \ncultural period in arctic Alaska, dating back some 4,000 \nyears. Nearly pristine barrier islands, lagoons, and beaches \nprovide habitat for fish, marine mammals, and migratory \nbirds while allowing legal harvest by local subsistence users. \nLIMITED FEDERAL FACILITIES. \nProclaimed Dec. 1, 1978. Boundary change: Dec. 2, 1980. \nAcreage\u2014649,096.15 Federal: 627,190.67 \nNonfederal: 21,905.48. \n19 \n \n \n \n \n \n \n \n \n \n \n \n \n   \n   \n  \n \n  \n \n \n  \n \n \n \n  \n   \n \n  \n \n \n \n \n \n \n  \n   \n   \n \nDenali National Park and \nDenali National Preserve \nPO Box 9\n \nMcKinley Park, AK 99755\u00ad\n0009 \n907\u00ad683\u00ad2253\n \nwww.nps.gov/dena\n \nThe park contains North America\u2019s highest mountain, \n20,310\u00adfoot Denali."
#           },
#           {
#             "attributes": {},
#             "file_id": "",
#             "filename": "",
#             "score":
 1971. \nAcreage\u201412.24 Federal: 12.03 Nonfederal: 0.21. \nPullman National  \nMon\nument \n11111 S. Forrestville Avenue \nChi\ncago, IL 60628 \n773\u00ad660\u00ad2341 \nwww.nps.gov/pull \nGeorge Pullman created an integrated manufacturing com\u00ad\np\nlex and residential community south of Chicago in the 1880s, \nwith the intention of retaining skilled workers for his varied \nrail cars assembled there.  The town of Pullman\u2019s design and \narchitecture still resonate with today\u2019s urban planners.  The \nname \u201cPull"
#           }
#         ]
#       }
#     ]
#   },
#   "response_metadata": {
#     "id": "resp-2468a1f4-2f6f-43fd-97d0-9549cb7111b8",
#     "created_at": 1759432145.0,
#     "model": "openai/gpt-4o",
#     "object": "response",
#     "status": "completed",
#     "model_name": "openai/gpt-4o"
#   },
#   "type": "ai",
#   "name": null,
#   "id": "msg_b0800904-6ffe-463f-9ecf-8bb3fd1b42cc",
#   "example": false,
#   "tool_calls": [],
#   "invalid_tool_calls": [],
#   "usage_metadata": null
# }

# %% [markdown]
# Similarly, we can use the same MCP server and query as in the earlier examples:

# %%
llm_with_mcp = llm.bind_tools([
  {
    "type": "mcp",
    "server_label": "NPS",
    "server_url": NPS_MCP_URL,
    "require_approval": "never",
  },
])

langchain_mcp_response = llm_with_mcp.invoke("Tell me about some parks in Rhode Island, and let me know if there are any upcoming events at them.")
simple_print(langchain_mcp_response)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/openai/v1/responses "HTTP/1.1 200 OK"
# {
#   "content": [
#     {
#       "type": "text",
#       "text": "Here are some parks in Rhode Island, along with information about their upcoming events:\n\n1. **Blackstone River Valley National Historical Park**: This park highlights America's entry into the Age of Industry, catalyzed by Samuel Slater's cotton spinning mill. It's a significant historical site that covers parts of Rhode Island and Massachusetts. Some upcoming events include:\n   - **Old Slater Mill Tour**: A 30-minute guided tour that explores Slater Mill's historical significance. Tours start at 10:30 AM, 12:30 PM, and 2:30 PM in front of the mill.\n   - **Revolutionary War Pension Files Transcription Event**: A series of fall programs where participants can transcribe pension records from the War for Independence. \n   - **Bat Walk**: A special night sky program featuring a bat walk scheduled for October 24, 2025.\n\n   More details and events can be found on their [website](https://www.nps.gov/blrv/index.htm).\n\n2. **Roger Williams National Memorial**: This park commemorates Roger Williams, the founder of Providence, Rhode Island, and highlights his contributions to religious freedom. Upcoming events include:\n   - **Roger Williams: The Separation of Church and State**: This program discusses the impact of Roger Williams on the separation of church and state, an essential principle of modern democracy.\n\n   Visit their [website](https://www.nps.gov/rowi/index.htm) for more information.\n\n3. **Touro Synagogue National Historic Site**: This is one of the most historically significant Jewish sites in America located in Newport, Rhode Island. While no upcoming events are currently listed, the synagogue continues to welcome visitors to explore its historical and architectural beauty. More information can be found on their [website](https://www.nps.gov/tosy/index.htm).\n\n4. **Washington-Rochambeau Revolutionary Route National Historic Trail**: Spanning several states, this trail celebrates the route taken by French and American armies during the Revolutionary War. There are no upcoming events listed for this trail, but it's a significant historical route to explore. Visit their [website](https://www.nps.gov/waro/index.htm) for more information.\n\nFor any of the parks, I recommend checking their official websites for the most current information and event scheduling.",
#       "annotations": []
#     }
#   ],
#   "additional_kwargs": {
#     "tool_outputs": [
#       {
#         "id": "mcp_list_c220761d-dbf6-45d7-9f41-462ff34c238f",
#         "server_label": "NPS",
#         "tools": [
#           {
#             "input_schema": {
#               "type": "object",
#               "properties": {
#                 "state_code": {
#                   "type": "string",
#                   "description": ""
#                 },
#                 "park_code": {
#                   "type": "string",
#                   "description": ""
#                 },
#                 "query": {
#                   "type": "string",
#                   "description": ""
#                 },
#                 "limit": {
#                   "type": "integer",
#                   "description": ""
#                 }
#               },
#               "required": [
#                 "state_code",
#                 "park_code",
#                 "query",
#                 "limit"
#               ]
#             },
#             "name": "search_parks",
#             "description": "Search for national parks by state, park code, or query string.\n\nArgs:\n    state_code: Two-letter state code (e.g., 'CA', 'NY')\n    park_code: Four-letter park code (e.g., 'yell', 'acad')\n    query: Search query for park names or descriptions\n    limit: Maximum number of results to return (default: 10)\n\nReturns:\n    JSON string with park information including name, description, website, and location"
#           },
#           {
#             "input_schema": {
#               "type": "object",
#               "properties": {
#                 "park_code": {
#                   "type": "string",
#                   "description": ""
#                 }
#               },
#               "required": [
#                 "park_code"
#               ]
#             },
#             "name": "get_park_alerts",
#             "description": "Get current alerts for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n\nReturns:\n    JSON string with current alerts for the park"
#           },
#           {
#             "input_schema": {
#               "type": "object",
#               "properties": {
#                 "park_code": {
#                   "type": "string",
#                   "description": ""
#                 },
#                 "limit": {
#                   "type": "integer",
#                   "description": ""
#                 }
#               },
#               "required": [
#                 "park_code",
#                 "limit"
#               ]
#             },
#             "name": "get_park_campgrounds",
#             "description": "Get campground information for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n    limit: Maximum number of campgrounds to return (default: 10)\n\nReturns:\n    JSON string with campground information including location, amenities, and fees"
#           },
#           {
#             "input_schema": {
#               "type": "object",
#               "properties": {
#                 "park_code": {
#                   "type": "string",
#                   "description": ""
#                 },
#                 "limit": {
#                   "type": "integer",
#                   "description": ""
#                 }
#               },
#               "required": [
#                 "park_code",
#                 "limit"
#               ]
#             },
#             "name": "get_park_events",
#             "description": "Get upcoming events for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n    limit: Maximum number of events to return (default: 10)\n\nReturns:\n    JSON string with event information including date, time, fee, and description"
#           },
#           {
#             "input_schema": {
#               "type": "object",
#               "properties": {
#                 "park_code": {
#                   "type": "string",
#                   "description": ""
#                 },
#                 "limit": {
#                   "type": "integer",
#                   "description": ""
#                 }
#               },
#               "required": [
#                 "park_code",
#                 "limit"
#               ]
#             },
#             "name": "get_visitor_centers",
#             "description": "Get visitor center information for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n    limit: Maximum number of visitor centers to return (default: 10)\n\nReturns:\n    JSON string with visitor center information including location, contact, and operating hours"
#           }
#         ],
#         "type": "mcp_list_tools"
#       },
#       {
#         "id": "call_CFu5iYONuDhOoCVKpfynzied",
#         "arguments": "{\"state_code\":\"RI\",\"limit\":5}",
#         "name": "search_parks",
#         "server_label": "NPS",
#         "type": "mcp_call",
#         "output": "{\n  \"total\": \"4\",\n  \"parks\": [\n    {\n      \"name\": \"Blackstone River Valley National Historical Park\",\n      \"code\": \"blrv\",\n      \"description\": \"The Blackstone River powered America's entry into the Age of Industry. The success of Samuel Slater's cotton spinning mill in Pawtucket, RI touched off a chain reaction that changed how people worked and where they lived. Learn how this revolution transformed the landscape of the Blackstone Valley and the United States. The Visitor Center at Old Slater Mill is currently open Thursday-Sunday, 10-4.\",\n      \"website\": \"https://www.nps.gov/blrv/index.htm\",\n      \"states\": \"RI,MA\",\n      \"designation\": \"National Historical Park\",\n      \"latitude\": \"41.8775792792\",\n      \"longitude\": \"-71.382433945\"\n    },\n    {\n      \"name\": \"Roger Williams National Memorial\",\n      \"code\": \"rowi\",\n      \"description\": \"\\\"I acknowledge that to molest any person, Jew or Gentile, for either professing doctrine, or practicing worship meerly religious or spiritual, is to persecute him, and such a person (whether his doctrine or practice be true or false) suffers persecution for conscience.\\\" -Roger Williams, 1644 Banished by the English and saved by the First Peoples, Roger Williams founded Providence here in 1636.\",\n      \"website\": \"https://www.nps.gov/rowi/index.htm\",\n      \"states\": \"RI\",\n      \"designation\": \"National Memorial\",\n      \"latitude\": \"41.8298955\",\n      \"longitude\": \"-71.41056665\"\n    },\n    {\n      \"name\": \"Touro Synagogue National Historic Site\",\n      \"code\": \"tosy\",\n      \"description\": \"Touro Synagogue, a building of exquisite beauty and design, steeped in history and ideals, and one of the most historically significant Jewish buildings in America, was designated a National Historic Site in 1946. Dedicated in 1763, it still serves an active congregation and each year greets over 30,000 visitors who come to see the magnificent interior and hear its remarkable story.\",\n      \"website\": \"https://www.nps.gov/tosy/index.htm\",\n      \"states\": \"RI\",\n      \"designation\": \"National Historic Site\",\n      \"latitude\": \"41.4893\",\n      \"longitude\": \"-71.3121\"\n    },\n    {\n      \"name\": \"Washington-Rochambeau Revolutionary Route National Historic Trail\",\n      \"code\": \"waro\",\n      \"description\": \"\\u201cOf the happiness I have enjoyed in our private friendship. The remembrance of which will be one of the most pleasing Circumstances of my life.\\u201d\\u2013 Comte de Rochambeau on his relationship with George Washington\",\n      \"website\": \"https://www.nps.gov/waro/index.htm\",\n      \"states\": \"MA,RI,CT,NY,NJ,PA,DE,MD,VA,DC\",\n      \"designation\": \"National Historic Trail\",\n      \"latitude\": \"40.0958204557\",\n      \"longitude\": \"-74.8563515109\"\n    }\n  ]\n}"
#       },
#       {
#         "id": "call_29ldGpFRiOWOC3r4AbaJZpjO",
#         "arguments": "{\"park_code\": \"blrv\", \"limit\": 5}",
#         "name": "get_park_events",
#         "server_label": "NPS",
#         "type": "mcp_call",
#         "output": "{\n  \"parkCode\": \"BLRV\",\n  \"totalEvents\": 14,\n  \"events\": [\n    {\n      \"title\": \"Old Slater Mill Tour\",\n      \"description\": \"<p>Join a Park Ranger on a tour of the Mill that started the American Industrial Revolution. These 30 minute guided tours investigate the historical significance of Slater Mill, and what valuable lessons the building still teachings us. Tours begin at 10:30 AM, 12:30 PM and 2:30 PM in front of the mill. Please arrive a few minutes early.</p>\\n<p>\\u00a0</p>\\n<p><u><em>Please Note:</em></u><em>\\u00a0</em><em>For visitor saftey, tours of Old Slater Mill will be modified or cancelled if the heat index is at or above 87 degrees Fahrenheit. A shortened 10 minute Ranger talk will be offered at the normal tour times. Visitors will have a brief period of access to the main part of the mill. For the latest weather information, call 401-725-8638.</em></p>\",\n      \"location\": \"67 Roosevelt Avenue, Pawtucket, RI 02860\",\n      \"dateStart\": \"\",\n      \"dateEnd\": \"\",\n      \"timeStart\": \"\",\n      \"timeEnd\": \"\",\n      \"feeInfo\": \"\",\n      \"isRecurring\": false,\n      \"parkCode\": \"\"\n    },\n    {\n      \"title\": \"Old Slater Mill Tour\",\n      \"description\": \"<p>Join a Park Ranger on a tour of the Mill that started the American Industrial Revolution. These 30 minute guided tours investigate the historical significance of Slater Mill, and what valuable lessons the building still teachings us. Tours begin at 10:30 AM, 12:30 PM and 2:30 PM in front of the mill. Please arrive a few minutes early.</p>\\n<p>\\u00a0</p>\\n<p><u><em>Please Note:</em></u><em>\\u00a0</em><em>For visitor saftey, tours of Old Slater Mill will be modified or cancelled if the heat index is at or above 87 degrees Fahrenheit. A shortened 10 minute Ranger talk will be offered at the normal tour times. Visitors will have a brief period of access to the main part of the mill. For the latest weather information, call 401-725-8638.</em></p>\",\n      \"location\": \"67 Roosevelt Avenue, Pawtucket, RI 02860\",\n      \"dateStart\": \"\",\n      \"dateEnd\": \"\",\n      \"timeStart\": \"\",\n      \"timeEnd\": \"\",\n      \"feeInfo\": \"\",\n      \"isRecurring\": false,\n      \"parkCode\": \"\"\n    },\n    {\n      \"title\": \"Revolutionary War Pension Files Transcription Event\",\n      \"description\": \"<p>Be a Citizen Archivist!</p>\\n<p>Join Blackstone River Valley National Historical Park and North Smithfield Heritage Association for a series of free evening programs this fall. Hosted from 6-7:30 PM at Heritage Hall, 101 Greene St., North Smithfield, RI. Open to all, no registration is required.\\u00a0</p>\\n<p>Participants will learn about the value of pensions from the War for Independence. Rangers will talk about these sources and teach participants how to transcribe records (available online) from the National Archives. Participants are encouraged to bring a laptop or tablet for typing records. WiFi will be available for all.\\u00a0</p>\\n<p>DATES: October 1, November 5, and December 3, 2025</p>\",\n      \"location\": \"Meet in Heritage Hall, located at 101 Greene St., North Smithfield, RI.\",\n      \"dateStart\": \"\",\n      \"dateEnd\": \"\",\n      \"timeStart\": \"\",\n      \"timeEnd\": \"\",\n      \"feeInfo\": \"\",\n      \"isRecurring\": false,\n      \"parkCode\": \"\"\n    },\n    {\n      \"title\": \"Blackstone River State Park Archaeology Tour\",\n      \"description\": \"<p>Enjoy a guided walk around\\u00a0Blackstone\\u00a0River State Park during Archaeology Month.\\u00a0Learn how\\u00a0archaeologists\\u00a0have\\u00a0uncovered the history of this\\u00a0site.\\u00a0</p>\\n<p>This walk will cover some uneven terrain.</p>\\n<p>Meet at\\u00a01075 Lower River Road, Lincoln, RI.</p>\",\n      \"location\": \"\",\n      \"dateStart\": \"\",\n      \"dateEnd\": \"\",\n      \"timeStart\": \"\",\n      \"timeEnd\": \"\",\n      \"feeInfo\": \"\",\n  ...
#       },
#       {
#         "id": "call_AdZSRLnZwaM6cnWlLndWYFSR",
#         "arguments": "{\"park_code\": \"rowi\", \"limit\": 5}",
#         "name": "get_park_events",
#         "server_label": "NPS",
#         "type": "mcp_call",
#         "output": "{\n  \"parkCode\": \"ROWI\",\n  \"totalEvents\": 2,\n  \"events\": [\n    {\n      \"title\": \"Roger Williams: The Separation of Church and State\",\n      \"description\": \"<p>A cornerstone of our democracy, Roger Williams established a clear limit to government authority. Join a National Park Service ranger as we explore the principles of freedom put into practice by Roger Williams and that changed the course of history.</p>\\n<p>The National Park Service is America's largest classroom. These free programs are part of a comprehenisve experience about Roger Williams's contributions to the principles of freedom in America today. Explore your National Memorial today!\\u00a0</p>\",\n      \"location\": \"The program begins at the historical well\",\n      \"dateStart\": \"\",\n      \"dateEnd\": \"\",\n      \"timeStart\": \"\",\n      \"timeEnd\": \"\",\n      \"feeInfo\": \"\",\n      \"isRecurring\": false,\n      \"parkCode\": \"\"\n    },\n    {\n      \"title\": \"Roger Williams: The Separation of Church and State\",\n      \"description\": \"<p>A cornerstone of our democracy, Roger Williams established a clear limit to government authority. Join a National Park Service ranger as we explore the principles of freedom put into practice by Roger Williams and that changed\\u00a0the\\u00a0course of history.</p>\\n<p>The National Park Service is America's largest classroom. These free programs are part of a comprehenisve experience about Roger Williams's contributions to the principles of freedom in America today. Explore your National Memorial today!\\u00a0</p>\",\n      \"location\": \"\",\n      \"dateStart\": \"\",\n      \"dateEnd\": \"\",\n      \"timeStart\": \"\",\n      \"timeEnd\": \"\",\n      \"feeInfo\": \"\",\n      \"isRecurring\": false,\n      \"parkCode\": \"\"\n    }\n  ]\n}"
#       },
#       {
#         "id": "call_11wyj8NSfP28Yx3bhEX9mFdR",
#         "arguments": "{\"park_code\": \"tosy\", \"limit\": 5}",
#         "name": "get_park_events",
#         "server_label": "NPS",
#         "type": "mcp_call",
#         "output": "{\"parkCode\": \"TOSY\", \"message\": \"No upcoming events found for this park\"}"
#       },
#       {
#         "id": "call_h3SMNVpyxgdlXVV78rQjJIjM",
#         "arguments": "{\"park_code\": \"waro\", \"limit\": 5}",
#         "name": "get_park_events",
#         "server_label": "NPS",
#         "type": "mcp_call",
#         "output": "{\"parkCode\": \"WARO\", \"message\": \"No upcoming events found for this park\"}"
#       }
#     ]
#   },
#   "response_metadata": {
#     "id": "resp-c1fd9d27-5d81-42f4-8263-e3f01e01a604",
#     "created_at": 1759432149.0,
#     "model": "openai/gpt-4o",
#     "object": "response",
#     "status": "completed",
#     "model_name": "openai/gpt-4o"
#   },
#   "type": "ai",
#   "name": null,
#   "id": "msg_eeb42f0c-4dc9-4cbd-ad15-73e7849b1021",
#   "example": false,
#   "tool_calls": [],
#   "invalid_tool_calls": [],
#   "usage_metadata": null
# }

# %% [markdown]
# There is a lot more that can be done with LangChain, but a deeper dive into LangChain is beyond the scope of this document.  The key point here is that if you want a higher level framework with more abstract concepts, LangChain can be a good fit for that purpose, and you can point it at your Llama Stack server and have it use the Responses API.
